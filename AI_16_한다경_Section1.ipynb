# %% [markdown]
# # 다음 분기에 어떤 게임을 설계해야 할까

# %% [markdown]
# ![스크린샷 2022-11-03 오후 5.35.03.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-11-03 오후 5.35.18.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2022-11-03 오후 5.35.33.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np 
import re
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

plt.style.use("default")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1c2db942-b09c-4974-a174-9786fa43beb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c2db942-b09c-4974-a174-9786fa43beb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 0.데이터 EDA

# %%
df_vgames = pd.read_csv('vgames2.csv')
df = df_vgames.copy()
df.head()
# Out:
#    Unnamed: 0                                            Name Platform  \
# 0           1                    Candace Kane's Candy Factory       DS
# 1           2                                  The Munchables      Wii
# 2           3  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP
# 3           4                Deal or No Deal: Special Edition       DS
# 4           5       Ben 10 Ultimate Alien: Cosmic Destruction      PS3
#
#      Year      Genre           Publisher NA_Sales EU_Sales JP_Sales  \
# 0  2008.0     Action           Destineer     0.04        0        0
# 1  2009.0     Action  Namco Bandai Games     0.17        0        0
# 2  2010.0  Adventure           Alchemist        0        0     0.02
# 3  2010.0       Misc           Zoo Games     0.04        0        0
# 4  2010.0   Platform         D3Publisher     0.12     0.09        0
#
#   Other_Sales
# 0           0
# 1        0.01
# 2           0
# 3           0
# 4        0.04

# %%
df = df.drop(df.columns[0], axis=1) # Unnamed: 0 column 삭제
df.head()
# Out:
#                                              Name Platform    Year      Genre  \
# 0                    Candace Kane's Candy Factory       DS  2008.0     Action
# 1                                  The Munchables      Wii  2009.0     Action
# 2  Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0  Adventure
# 3                Deal or No Deal: Special Edition       DS  2010.0       Misc
# 4       Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0   Platform
#
#             Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 0           Destineer     0.04        0        0           0
# 1  Namco Bandai Games     0.17        0        0        0.01
# 2           Alchemist        0        0     0.02           0
# 3           Zoo Games     0.04        0        0           0
# 4         D3Publisher     0.12     0.09        0        0.04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16598 non-null  object
#  1   Platform     16598 non-null  object
#  2   Year         16327 non-null  float64
#  3   Genre        16548 non-null  object
#  4   Publisher    16540 non-null  object
#  5   NA_Sales     16598 non-null  object
#  6   EU_Sales     16598 non-null  object
#  7   JP_Sales     16598 non-null  object
#  8   Other_Sales  16598 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (16598, 9)

# %% [markdown]
# ## 1.데이터 전처리

# %% [markdown]
# ### 1-1) 중복 데이터

# %%
# 중복 데이터 확인
df[df.duplicated(keep=False)] # keep=False : 중복된 값 모두 확인
# Out:
#                              Name Platform  Year    Genre Publisher NA_Sales  \
# 8055  Wii de Asobu: Metroid Prime      Wii   NaN  Shooter  Nintendo        0
# 9184  Wii de Asobu: Metroid Prime      Wii   NaN  Shooter  Nintendo        0
#
#      EU_Sales JP_Sales Other_Sales
# 8055        0     0.02           0
# 9184        0     0.02           0

# %%
# 중복 데이터 제거
df = df.drop_duplicates().reset_index(drop=True)
df.shape
# Out:
# (16597, 9)

# %% [markdown]
# ### 1-2) 결측치

# %% [markdown]
# #### Genre

# %% [markdown]
# ##### Genre 결측치 확인

# %%
# Genre
Genre_null = df[df.Genre.isnull()]
Genre_null
# Out:
#                                               Name Platform    Year Genre  \
# 50                        Ape Escape: On the Loose      PSP  2005.0   NaN
# 408                                    NBA Ballers       XB  2004.0   NaN
# 1328                                    NFL Street       XB  2004.0   NaN
# 1582                SingStar Singalong With Disney      PS2  2008.0   NaN
# 1971                           Pokemon X/Pokemon Y      3DS  2013.0   NaN
# 2043                                 NASCAR Racing       PS  1996.0   NaN
# 2497              Jurassic Park III: Island Attack      GBA  2001.0   NaN
# 3353                   The Godfather: Dons Edition      PS3  2007.0   NaN
# 3363                  Ski-Doo Snowmobile Challenge     X360  2009.0   NaN
# 3470            Batman Beyond: Return of the Joker      N64  2000.0   NaN
# 3515      Princess Saver! Eternal Love for My Lady      PS2  2010.0   NaN
# 3932                             MVP Baseball 2004      PS2  2004.0   NaN
# ...

# %%
Genre_null.shape
# Out:
# (50, 9)

# %%
Genre_null_name = Genre_null.Name
Genre_null_name.duplicated().sum()
# Out:
# 0

# %%
Genre_null_name
# Out:
# 50                          Ape Escape: On the Loose
# 408                                      NBA Ballers
# 1328                                      NFL Street
# 1582                  SingStar Singalong With Disney
# 1971                             Pokemon X/Pokemon Y
# 2043                                   NASCAR Racing
# 2497                Jurassic Park III: Island Attack
# 3353                     The Godfather: Dons Edition
# 3363                    Ski-Doo Snowmobile Challenge
# 3470              Batman Beyond: Return of the Joker
# 3515        Princess Saver! Eternal Love for My Lady
# 3932                               MVP Baseball 2004
# 4148                             Grand Theft Auto IV
# 4349                       Brain Quest: Grades 5 & 6
# 4545               Dragon Ball Z: Ultimate Tenkaichi
# 4598                                       Wii Party
# 4935                                Astonishia Story
# 5668                                    Chrono Cross
# ...

# %%
for name in Genre_null_name:
  tup = np.where(df['Name'] == name)  # tuple로 값 반환
  print(tup)          # tuple -> array로 변환
# Out:
# (array([50]),)
# (array([ 408, 3337]),)
# (array([ 1328,  4953, 13483]),)
# (array([1582]),)
# (array([1971]),)
# (array([2043]),)
# (array([2497]),)
# (array([3353]),)
# (array([ 3363,  8383, 14896]),)
# (array([3470, 5172]),)
# (array([3515]),)
# (array([  917,  3932, 16059]),)
# (array([ 4148, 13925, 16474]),)
# (array([4349]),)
# (array([4545, 8434]),)
# (array([4598]),)
# (array([4935]),)
# (array([5668]),)
# (array([ 1210,  2686,  3584,  5713, 16056]),)
# (array([5945]),)
# (array([6798]),)
# (array([7143]),)
# (array([ 2595,  3795,  7336, 13293, 16277]),)
# (array([7526]),)
# (array([7797]),)
# (array([9487]),)
# (array([10431, 12772, 16210]),)
# (array([10500]),)
# (array([10873, 16531]),)
# (array([11049]),)
# (array([11062]),)
# (array([ 3505,  4990,  5050, 11267, 13064]),)
# (array([11495]),)
# (array([ 6608, 11667, 15008]),)
# (array([11002, 11698, 12234]),)
# (array([ 6181, 12313]),)
# (array([12330]),)
# (array([12339]),)
# (array([12869]),)
# (array([12981]),)
# ...

# %% [markdown]
# ##### Genre 결측치 직접 확인 후, 대입

# %%
df.loc[[50]] # 1
# Out:
#                         Name Platform    Year Genre  \
# 50  Ape Escape: On the Loose      PSP  2005.0   NaN
#
#                       Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 50  Sony Computer Entertainment     0.52     0.01     0.12        0.05

# %%
df.loc[[408, 3337]] # 2
# Out:
#              Name Platform    Year   Genre     Publisher NA_Sales EU_Sales  \
# 408   NBA Ballers       XB  2004.0     NaN  Midway Games     0.37     0.11
# 3337  NBA Ballers      PS2  2004.0  Sports  Midway Games     0.81     0.63
#
#      JP_Sales Other_Sales
# 408         0        0.02
# 3337        0        0.21

# %%
list = [408, 3337]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Sports'   # 수정

df.loc[list]
# Out:
#              Name Platform    Year   Genre     Publisher NA_Sales EU_Sales  \
# 408   NBA Ballers       XB  2004.0  Sports  Midway Games     0.37     0.11
# 3337  NBA Ballers      PS2  2004.0  Sports  Midway Games     0.81     0.63
#
#      JP_Sales Other_Sales
# 408         0        0.02
# 3337        0        0.21

# %%
df.loc[[1328,  4953, 13483]] # 3
# Out:
#              Name Platform    Year   Genre        Publisher NA_Sales EU_Sales  \
# 1328   NFL Street       XB  2004.0     NaN  Electronic Arts     0.49     0.15
# 4953   NFL Street      PS2  2004.0  Sports  Electronic Arts     1.15     0.08
# 13483  NFL Street       GC  2004.0  Sports  Electronic Arts     0.27     0.07
#
#       JP_Sales Other_Sales
# 1328         0        0.02
# 4953         0        0.19
# 13483        0        0.01

# %%
list = [1328,  4953, 13483]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Sports'   # 수정

df.loc[list]
# Out:
#              Name Platform    Year   Genre        Publisher NA_Sales EU_Sales  \
# 1328   NFL Street       XB  2004.0  Sports  Electronic Arts     0.49     0.15
# 4953   NFL Street      PS2  2004.0  Sports  Electronic Arts     1.15     0.08
# 13483  NFL Street       GC  2004.0  Sports  Electronic Arts     0.27     0.07
#
#       JP_Sales Other_Sales
# 1328         0        0.02
# 4953         0        0.19
# 13483        0        0.01

# %%
df.loc[[1582]] # 4
# Out:
#                                 Name Platform    Year Genre  \
# 1582  SingStar Singalong With Disney      PS2  2008.0   NaN
#
#                         Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 1582  Sony Computer Entertainment        0     0.04        0        0.57

# %%
df.loc[[3363,  8383, 14896]] # 9
# Out:
#                                Name Platform    Year   Genre     Publisher  \
# 3363   Ski-Doo Snowmobile Challenge     X360  2009.0     NaN  Valcon Games
# 8383   Ski-Doo Snowmobile Challenge      Wii  2009.0  Racing  Valcon Games
# 14896  Ski-Doo Snowmobile Challenge      PS3  2009.0  Racing         PQube
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 3363      0.03        0        0           0
# 8383      0.08        0        0        0.01
# 14896      0.1        0        0        0.01

# %%
list = [3363,  8383, 14896]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Racing'   # 수정

df.loc[list]
# Out:
#                                Name Platform    Year   Genre     Publisher  \
# 3363   Ski-Doo Snowmobile Challenge     X360  2009.0  Racing  Valcon Games
# 8383   Ski-Doo Snowmobile Challenge      Wii  2009.0  Racing  Valcon Games
# 14896  Ski-Doo Snowmobile Challenge      PS3  2009.0  Racing         PQube
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 3363      0.03        0        0           0
# 8383      0.08        0        0        0.01
# 14896      0.1        0        0        0.01

# %%
df.loc[[3470, 5172]] # 10
# Out:
#                                     Name Platform    Year   Genre Publisher  \
# 3470  Batman Beyond: Return of the Joker      N64  2000.0     NaN   Ubisoft
# 5172  Batman Beyond: Return of the Joker       PS  2000.0  Action   Ubisoft
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 3470     0.07     0.02        0           0
# 5172     0.09     0.06        0        0.01

# %%
list = [3470, 5172]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Action'   # 수정

df.loc[list]
# Out:
#                                     Name Platform    Year   Genre Publisher  \
# 3470  Batman Beyond: Return of the Joker      N64  2000.0  Action   Ubisoft
# 5172  Batman Beyond: Return of the Joker       PS  2000.0  Action   Ubisoft
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 3470     0.07     0.02        0           0
# 5172     0.09     0.06        0        0.01

# %%
df.loc[[917,  3932, 16059]] # 12
# Out:
#                     Name Platform    Year   Genre        Publisher NA_Sales  \
# 917    MVP Baseball 2004       GC  2004.0  Sports  Electronic Arts      0.2
# 3932   MVP Baseball 2004      PS2  2004.0     NaN  Electronic Arts      1.1
# 16059  MVP Baseball 2004       XB  2004.0  Sports  Electronic Arts     0.44
#
#       EU_Sales JP_Sales Other_Sales
# 917       0.05        0        0.01
# 3932      0.06        0        0.18
# 16059     0.13        0        0.02

# %%
list = [917,  3932, 16059]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Sports'   # 수정

df.loc[list]
# Out:
#                     Name Platform    Year   Genre        Publisher NA_Sales  \
# 917    MVP Baseball 2004       GC  2004.0  Sports  Electronic Arts      0.2
# 3932   MVP Baseball 2004      PS2  2004.0  Sports  Electronic Arts      1.1
# 16059  MVP Baseball 2004       XB  2004.0  Sports  Electronic Arts     0.44
#
#       EU_Sales JP_Sales Other_Sales
# 917       0.05        0        0.01
# 3932      0.06        0        0.18
# 16059     0.13        0        0.02

# %%
df.loc[[4148, 13925, 16474]] # 13
# Out:
#                       Name Platform    Year   Genre             Publisher  \
# 4148   Grand Theft Auto IV       PC  2008.0     NaN  Take-Two Interactive
# 13925  Grand Theft Auto IV     X360  2008.0  Action  Take-Two Interactive
# 16474  Grand Theft Auto IV      PS3  2008.0  Action  Take-Two Interactive
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 4148      0.01     0.79        0        0.08
# 13925     6.76      3.1     0.14        1.03
# 16474     4.76     3.76     0.44        1.62

# %%
list = [4148, 13925, 16474]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Action'   # 수정

df.loc[list]
# Out:
#                       Name Platform    Year   Genre             Publisher  \
# 4148   Grand Theft Auto IV       PC  2008.0  Action  Take-Two Interactive
# 13925  Grand Theft Auto IV     X360  2008.0  Action  Take-Two Interactive
# 16474  Grand Theft Auto IV      PS3  2008.0  Action  Take-Two Interactive
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 4148      0.01     0.79        0        0.08
# 13925     6.76      3.1     0.14        1.03
# 16474     4.76     3.76     0.44        1.62

# %%
df.loc[[4545, 8434]] # 15
# Out:
#                                    Name Platform    Year     Genre  \
# 4545  Dragon Ball Z: Ultimate Tenkaichi     X360  2011.0       NaN
# 8434  Dragon Ball Z: Ultimate Tenkaichi      PS3  2011.0  Fighting
#
#                Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 4545  Namco Bandai Games     0.39      0.1     0.01        0.04
# 8434  Namco Bandai Games     0.27     0.18     0.09        0.08

# %%
list = [4545, 8434]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Fighting'   # 수정

df.loc[list]
# Out:
#                                    Name Platform    Year     Genre  \
# 4545  Dragon Ball Z: Ultimate Tenkaichi     X360  2011.0  Fighting
# 8434  Dragon Ball Z: Ultimate Tenkaichi      PS3  2011.0  Fighting
#
#                Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 4545  Namco Bandai Games     0.39      0.1     0.01        0.04
# 8434  Namco Bandai Games     0.27     0.18     0.09        0.08

# %%
df.loc[[1210,  2686,  3584,  5713, 16056]] # 19
# Out:
#                                Name Platform    Year      Genre  \
# 1210   Back to the Future: The Game      PS3  2011.0  Adventure
# 2686   Back to the Future: The Game      PS4  2015.0  Adventure
# 3584   Back to the Future: The Game     X360  2015.0  Adventure
# 5713   Back to the Future: The Game     XOne  2015.0        NaN
# 16056  Back to the Future: The Game      Wii  2011.0  Adventure
#
#             Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 1210   Telltale Games     0.07     0.01        0        0.01
# 2686   Telltale Games      0.1     0.04        0        0.03
# 3584   Telltale Games     0.02     0.01        0           0
# 5713   Telltale Games        0     0.02        0           0
# 16056  Telltale Games     0.05        0        0           0

# %%
list = [1210,  2686,  3584,  5713, 16056]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Adventure'   # 수정

df.loc[list]
# Out:
#                                Name Platform    Year      Genre  \
# 1210   Back to the Future: The Game      PS3  2011.0  Adventure
# 2686   Back to the Future: The Game      PS4  2015.0  Adventure
# 3584   Back to the Future: The Game     X360  2015.0  Adventure
# 5713   Back to the Future: The Game     XOne  2015.0  Adventure
# 16056  Back to the Future: The Game      Wii  2011.0  Adventure
#
#             Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 1210   Telltale Games     0.07     0.01        0        0.01
# 2686   Telltale Games      0.1     0.04        0        0.03
# 3584   Telltale Games     0.02     0.01        0           0
# 5713   Telltale Games        0     0.02        0           0
# 16056  Telltale Games     0.05        0        0           0

# %%
df.loc[[2595,  3795,  7336, 13293, 16277]] # 23
# Out:
#                 Name Platform    Year   Genre        Publisher NA_Sales  \
# 2595   Madden NFL 11     X360  2010.0  Sports  Electronic Arts     2.38
# 3795   Madden NFL 11      PSP  2010.0  Sports  Electronic Arts     0.35
# 7336   Madden NFL 11      PS2  2010.0     NaN  Electronic Arts     0.41
# 13293  Madden NFL 11      PS3  2010.0  Sports  Electronic Arts     2.04
# 16277  Madden NFL 11      Wii     NaN  Sports          Unknown      0.7
#
#       EU_Sales JP_Sales Other_Sales
# 2595      0.12        0        0.18
# 3795         0        0        0.03
# 7336      0.02        0        0.07
# 13293     0.15        0        0.19
# 16277        0        0         50K

# %%
list = [2595,  3795,  7336, 13293, 16277]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Sports'   # 수정

df.loc[list]
# Out:
#                 Name Platform    Year   Genre        Publisher NA_Sales  \
# 2595   Madden NFL 11     X360  2010.0  Sports  Electronic Arts     2.38
# 3795   Madden NFL 11      PSP  2010.0  Sports  Electronic Arts     0.35
# 7336   Madden NFL 11      PS2  2010.0  Sports  Electronic Arts     0.41
# 13293  Madden NFL 11      PS3  2010.0  Sports  Electronic Arts     2.04
# 16277  Madden NFL 11      Wii     NaN  Sports          Unknown      0.7
#
#       EU_Sales JP_Sales Other_Sales
# 2595      0.12        0        0.18
# 3795         0        0        0.03
# 7336      0.02        0        0.07
# 13293     0.15        0        0.19
# 16277        0        0         50K

# %%
df.loc[[10431, 12772, 16210]] # 27
# Out:
#                                         Name Platform    Year   Genre  \
# 10431  The Mummy: Tomb of the Dragon Emperor      Wii  2008.0     NaN
# 12772  The Mummy: Tomb of the Dragon Emperor       DS  2008.0  Action
# 16210  The Mummy: Tomb of the Dragon Emperor      PS2  2008.0  Action
#
#            Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 10431  Vivendi Games     0.08        0        0        0.01
# 12772  Vivendi Games     0.08        0        0        0.01
# 16210  Vivendi Games     0.12      0.1        0        0.03

# %%
list = [10431, 12772, 16210]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Action'   # 수정

df.loc[list]
# Out:
#                                         Name Platform    Year   Genre  \
# 10431  The Mummy: Tomb of the Dragon Emperor      Wii  2008.0  Action
# 12772  The Mummy: Tomb of the Dragon Emperor       DS  2008.0  Action
# 16210  The Mummy: Tomb of the Dragon Emperor      PS2  2008.0  Action
#
#            Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 10431  Vivendi Games     0.08        0        0        0.01
# 12772  Vivendi Games     0.08        0        0        0.01
# 16210  Vivendi Games     0.12      0.1        0        0.03

# %%
df.loc[[10873, 16531]] # 29
# Out:
#                                     Name Platform    Year Genre  \
# 10873  Karaoke Revolution Glee: Volume 3      Wii  2011.0   NaN
# 16531  Karaoke Revolution Glee: Volume 3     X360  2011.0  Misc
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 10873  Konami Digital Entertainment     0.24     0.04        0        0.02
# 16531  Konami Digital Entertainment     0.13        0        0        0.01

# %%
list = [10873, 16531]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Misc'   # 수정

df.loc[list]
# Out:
#                                     Name Platform    Year Genre  \
# 10873  Karaoke Revolution Glee: Volume 3      Wii  2011.0  Misc
# 16531  Karaoke Revolution Glee: Volume 3     X360  2011.0  Misc
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 10873  Konami Digital Entertainment     0.24     0.04        0        0.02
# 16531  Konami Digital Entertainment     0.13        0        0        0.01

# %%
df.loc[[3505,  4990,  5050, 11267, 13064]] # 32
# Out:
#                                     Name Platform    Year     Genre Publisher  \
# 3505   Cloudy With a Chance of Meatballs     X360  2009.0  Platform   Ubisoft
# 4990   Cloudy With a Chance of Meatballs      PSP  2009.0  Platform   Ubisoft
# 5050   Cloudy With a Chance of Meatballs       DS  2009.0  Platform   Ubisoft
# 11267  Cloudy With a Chance of Meatballs      PS3  2009.0       NaN   Ubisoft
# 13064  Cloudy With a Chance of Meatballs      Wii  2009.0  Platform   Ubisoft
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 3505      0.07     0.01        0        0.01
# 4990      0.07        0        0        0.01
# 5050       0.2     0.01        0         20K
# 11267     0.09     0.01        0        0.01
# 13064     0.11        0        0        0.01

# %%
list = [3505,  4990,  5050, 11267, 13064]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Platform'   # 수정

df.loc[list]
# Out:
#                                     Name Platform    Year     Genre Publisher  \
# 3505   Cloudy With a Chance of Meatballs     X360  2009.0  Platform   Ubisoft
# 4990   Cloudy With a Chance of Meatballs      PSP  2009.0  Platform   Ubisoft
# 5050   Cloudy With a Chance of Meatballs       DS  2009.0  Platform   Ubisoft
# 11267  Cloudy With a Chance of Meatballs      PS3  2009.0  Platform   Ubisoft
# 13064  Cloudy With a Chance of Meatballs      Wii  2009.0  Platform   Ubisoft
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 3505      0.07     0.01        0        0.01
# 4990      0.07        0        0        0.01
# 5050       0.2     0.01        0         20K
# 11267     0.09     0.01        0        0.01
# 13064     0.11        0        0        0.01

# %%
df.loc[[6608, 11667, 15008]] # 34
# Out:
#                                               Name Platform    Year    Genre  \
# 6608   The History Channel: Battle for the Pacific      PS3  2008.0  Shooter
# 11667  The History Channel: Battle for the Pacific      Wii  2007.0      NaN
# 15008  The History Channel: Battle for the Pacific     X360  2007.0  Shooter
#
#         Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 6608   Activision     0.07        0        0        0.01
# 11667  Activision      0.1        0        0        0.01
# 15008  Activision     0.05        0        0           0

# %%
list = [6608, 11667, 15008]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Shooter'   # 수정

df.loc[list]
# Out:
#                                               Name Platform    Year    Genre  \
# 6608   The History Channel: Battle for the Pacific      PS3  2008.0  Shooter
# 11667  The History Channel: Battle for the Pacific      Wii  2007.0  Shooter
# 15008  The History Channel: Battle for the Pacific     X360  2007.0  Shooter
#
#         Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 6608   Activision     0.07        0        0        0.01
# 11667  Activision      0.1        0        0        0.01
# 15008  Activision     0.05        0        0           0

# %%
df.loc[[11002, 11698, 12234]] # 35
# Out:
#                  Name Platform    Year      Genre Publisher NA_Sales EU_Sales  \
# 11002  Time Travelers      PSP  2012.0  Adventure   Level 5        0        0
# 11698  Time Travelers      PSV  2012.0        NaN   Level 5        0        0
# 12234  Time Travelers      3DS  2012.0  Adventure   Unknown        0        0
#
#       JP_Sales Other_Sales
# 11002     0.01           0
# 11698     0.05           0
# 12234     0.04           0

# %%
list = [11002, 11698, 12234]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Adventure'   # 수정

df.loc[list]
# Out:
#                  Name Platform    Year      Genre Publisher NA_Sales EU_Sales  \
# 11002  Time Travelers      PSP  2012.0  Adventure   Level 5        0        0
# 11698  Time Travelers      PSV  2012.0  Adventure   Level 5        0        0
# 12234  Time Travelers      3DS  2012.0  Adventure   Unknown        0        0
#
#       JP_Sales Other_Sales
# 11002     0.01           0
# 11698     0.05           0
# 12234     0.04           0

# %%
df.loc[[6181, 12313]] # 36
# Out:
#              Name Platform    Year   Genre   Publisher NA_Sales EU_Sales  \
# 6181   Ice Hockey      NES  1988.0  Sports    Nintendo     1.27     0.32
# 12313  Ice Hockey     2600  1980.0     NaN  Activision     0.46     0.03
#
#       JP_Sales Other_Sales
# 6181      0.78        0.05
# 12313        0        0.01

# %%
list = [6181, 12313]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Sports'   # 수정

df.loc[list]
# Out:
#              Name Platform    Year   Genre   Publisher NA_Sales EU_Sales  \
# 6181   Ice Hockey      NES  1988.0  Sports    Nintendo     1.27     0.32
# 12313  Ice Hockey     2600  1980.0  Sports  Activision     0.46     0.03
#
#       JP_Sales Other_Sales
# 6181      0.78        0.05
# 12313        0        0.01

# %%
df.loc[[1047,  7183, 13206, 14064, 14929]] # 42
# Out:
#                     Name Platform    Year   Genre   Publisher NA_Sales  \
# 1047   Skylanders Giants      3DS  2012.0  Action  Activision     0.12
# 7183   Skylanders Giants     WiiU  2012.0  Action  Activision     0.23
# 13206  Skylanders Giants     X360  2012.0  Action  Activision     0.75
# 14064  Skylanders Giants      Wii  2012.0  Action  Activision     1.56
# 14929  Skylanders Giants      PS3  2012.0     NaN  Activision     0.35
#
#       EU_Sales JP_Sales Other_Sales
# 1047      0.01        0        0.01
# 7183      0.12        0        0.04
# 13206     0.45        0        0.11
# 14064     0.88        0        0.22
# 14929     0.52        0        0.22

# %%
list = [1047,  7183, 13206, 14064, 14929]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Action'   # 수정

df.loc[list]
# Out:
#                     Name Platform    Year   Genre   Publisher NA_Sales  \
# 1047   Skylanders Giants      3DS  2012.0  Action  Activision     0.12
# 7183   Skylanders Giants     WiiU  2012.0  Action  Activision     0.23
# 13206  Skylanders Giants     X360  2012.0  Action  Activision     0.75
# 14064  Skylanders Giants      Wii  2012.0  Action  Activision     1.56
# 14929  Skylanders Giants      PS3  2012.0  Action  Activision     0.35
#
#       EU_Sales JP_Sales Other_Sales
# 1047      0.01        0        0.01
# 7183      0.12        0        0.04
# 13206     0.45        0        0.11
# 14064     0.88        0        0.22
# 14929     0.52        0        0.22

# %%
df.loc[[2561,  4859,  9557, 15210]] # 43
# Out:
#                             Name Platform    Year    Genre        Publisher  \
# 2561   James Bond 007: Nightfire       GC  2002.0  Shooter  Electronic Arts
# 4859   James Bond 007: Nightfire      PS2  2002.0  Shooter  Electronic Arts
# 9557   James Bond 007: Nightfire      GBA  2003.0  Shooter  Electronic Arts
# 15210  James Bond 007: Nightfire       XB  2002.0      NaN  Electronic Arts
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 2561       0.6     0.16        0        0.02
# 4859      1.45     1.29     0.12        0.46
# 9557       0.1     0.04        0           0
# 15210     0.58     220K        0        0.03

# %%
list = [2561,  4859,  9557, 15210]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Shooter'   # 수정

df.loc[list]
# Out:
#                             Name Platform    Year    Genre        Publisher  \
# 2561   James Bond 007: Nightfire       GC  2002.0  Shooter  Electronic Arts
# 4859   James Bond 007: Nightfire      PS2  2002.0  Shooter  Electronic Arts
# 9557   James Bond 007: Nightfire      GBA  2003.0  Shooter  Electronic Arts
# 15210  James Bond 007: Nightfire       XB  2002.0  Shooter  Electronic Arts
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 2561       0.6     0.16        0        0.02
# 4859      1.45     1.29     0.12        0.46
# 9557       0.1     0.04        0           0
# 15210     0.58     220K        0        0.03

# %%
df.loc[[1497, 10045, 13329, 16430]] # 47
# Out:
#                                     Name Platform    Year   Genre Publisher  \
# 1497   Cars: Mater-National Championship       DS  2007.0  Racing       THQ
# 10045  Cars: Mater-National Championship      PS3  2007.0  Racing       THQ
# 13329  Cars: Mater-National Championship      PS2  2007.0  Racing       THQ
# 16430  Cars: Mater-National Championship     X360  2007.0     NaN       THQ
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 1497      0.63     0.01        0        0.05
# 10045     0.37     0.01       0M        0.03
# 13329     0.12     0.09       0M        0.03
# 16430     0.13        0        0        0.01

# %%
list = [1497, 10045, 13329, 16430]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Racing'   # 수정

df.loc[list]
# Out:
#                                     Name Platform    Year   Genre Publisher  \
# 1497   Cars: Mater-National Championship       DS  2007.0  Racing       THQ
# 10045  Cars: Mater-National Championship      PS3  2007.0  Racing       THQ
# 13329  Cars: Mater-National Championship      PS2  2007.0  Racing       THQ
# 16430  Cars: Mater-National Championship     X360  2007.0  Racing       THQ
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 1497      0.63     0.01        0        0.05
# 10045     0.37     0.01       0M        0.03
# 13329     0.12     0.09       0M        0.03
# 16430     0.13        0        0        0.01

# %%
df.loc[[3846, 11355, 16554]] # 48
# Out:
#                       Name Platform    Year       Genre    Publisher NA_Sales  \
# 3846   Apache: Air Assault      PS3  2010.0  Simulation   Activision     0.11
# 11355  Apache: Air Assault     X360  2010.0  Simulation   Activision     0.12
# 16554  Apache: Air Assault       PC  2010.0         NaN  Just Flight        0
#
#       EU_Sales JP_Sales Other_Sales
# 3846      0.07        0        0.03
# 11355     0.04        0        0.01
# 16554     0.03        0        0.01

# %%
list = [3846, 11355, 16554]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Simulation'   # 수정

df.loc[list]
# Out:
#                       Name Platform    Year       Genre    Publisher NA_Sales  \
# 3846   Apache: Air Assault      PS3  2010.0  Simulation   Activision     0.11
# 11355  Apache: Air Assault     X360  2010.0  Simulation   Activision     0.12
# 16554  Apache: Air Assault       PC  2010.0  Simulation  Just Flight        0
#
#       EU_Sales JP_Sales Other_Sales
# 3846      0.07        0        0.03
# 11355     0.04        0        0.01
# 16554     0.03        0        0.01

# %%
df.loc[[3451,  4923,  5317,  8185, 11189, 16586]] # 49
# Out:
#                                Name Platform    Year   Genre        Publisher  \
# 3451   Need for Speed Underground 2       DS  2005.0  Racing  Electronic Arts
# 4923   Need for Speed Underground 2      PS2  2004.0  Racing  Electronic Arts
# 5317   Need for Speed Underground 2      GBA  2004.0  Racing  Electronic Arts
# 8185   Need for Speed Underground 2       GC  2004.0  Racing  Electronic Arts
# 11189  Need for Speed Underground 2       PC  2004.0  Racing  Electronic Arts
# 16586  Need for Speed Underground 2       XB  2004.0     NaN  Electronic Arts
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 3451      0.11     0.02        0        0.01
# 4923      2.71     3.02     0.08        1.09
# 5317      0.31     0.12        0        0.01
# 8185       0.7     0.39     0.01        0.03
# 11189        0     0.06        0        0.01
# 16586     1.38      0.8        0         0.1

# %%
list = [3451,  4923,  5317,  8185, 11189, 16586]   # 수정
for idx in list:
  df.loc[idx,'Genre'] = 'Racing'   # 수정

df.loc[list]
# Out:
#                                Name Platform    Year   Genre        Publisher  \
# 3451   Need for Speed Underground 2       DS  2005.0  Racing  Electronic Arts
# 4923   Need for Speed Underground 2      PS2  2004.0  Racing  Electronic Arts
# 5317   Need for Speed Underground 2      GBA  2004.0  Racing  Electronic Arts
# 8185   Need for Speed Underground 2       GC  2004.0  Racing  Electronic Arts
# 11189  Need for Speed Underground 2       PC  2004.0  Racing  Electronic Arts
# 16586  Need for Speed Underground 2       XB  2004.0  Racing  Electronic Arts
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 3451      0.11     0.02        0        0.01
# 4923      2.71     3.02     0.08        1.09
# 5317      0.31     0.12        0        0.01
# 8185       0.7     0.39     0.01        0.03
# 11189        0     0.06        0        0.01
# 16586     1.38      0.8        0         0.1

# %% [markdown]
# ##### Genre 결측치 data imputaion 후, 확인

# %%
df[df.Genre.isnull()].shape
# Out:
# (30, 9)

# %%
df_genre = df
df_genre.shape
# Out:
# (16597, 9)

# %% [markdown]
# #### Publisher

# %% [markdown]
# ##### Publisher 결측치 확인

# %%
pub_null = df[df.Publisher.isnull()]
pub_null
# Out:
#                                                     Name Platform    Year  \
# 272                                   UK Truck Simulator       PC  2010.0
# 1313      All Grown Up!: Game Boy Advance Video Volume 1      GBA  2004.0
# 1560   Teenage Mutant Ninja Turtles: Game Boy Advance...      GBA  2004.0
# 1789   Nicktoons Collection: Game Boy Advance Video V...      GBA  2004.0
# 1879                      Monster Hunter Frontier Online      PS3     NaN
# 1961   Nicktoons Collection: Game Boy Advance Video V...      GBA  2004.0
# 2070                                      World of Tanks     X360     NaN
# 2970                                Chou Soujuu Mecha MG       DS     NaN
# 3184                        Action Man-Operation Extreme       PS     NaN
# 3412                                   Dance with Devils      PSV  2016.0
# 3533                           B.L.U.E.: Legend of Water       PS     NaN
# 3562                          wwe Smackdown vs. Raw 2006      PS2     NaN
# ...

# %%
pub_null.shape
# Out:
# (58, 9)

# %%
pub_name = pub_null.Name
pub_name.duplicated().sum()
# Out:
# 0

# %%
for name in pub_name:
  tup = np.where(df['Name'] == name)  # tuple로 값 반환
  print(tup)          # tuple -> array로 변환
# Out:
# (array([272]),)
# (array([1313]),)
# (array([1560]),)
# (array([1789]),)
# (array([1879, 7014]),)
# (array([1961]),)
# (array([  27, 2070]),)
# (array([2970]),)
# (array([3184]),)
# (array([3412]),)
# (array([3533]),)
# (array([3562]),)
# (array([3639]),)
# (array([3684]),)
# (array([4308]),)
# (array([4367]),)
# (array([5207]),)
# (array([5245]),)
# (array([5387]),)
# (array([6209]),)
# (array([ 6392, 15057]),)
# (array([7370]),)
# (array([7984]),)
# (array([8038]),)
# (array([8236]),)
# (array([8355]),)
# (array([ 8651, 10044, 14728, 15704]),)
# (array([8873]),)
# (array([9128]),)
# (array([9683]),)
# (array([ 5901,  9876,  9895, 15811]),)
# (array([10155]),)
# (array([10222]),)
# (array([11308]),)
# (array([11497]),)
# (array([ 7310, 11640]),)
# (array([11675]),)
# (array([12125]),)
# (array([12175]),)
# (array([12467]),)
# (array([12559]),)
# (array([12899]),)
# (array([13181]),)
# (array([13203]),)
# (array([13449]),)
# (array([13765]),)
# (array([13809]),)
# (array([13836]),)
# ...

# %% [markdown]
# ##### Publisher 결측치 직접 확인 후, 대입

# %%
df.loc[[1879, 7014]] # 1
# Out:
#                                 Name Platform    Year         Genre Publisher  \
# 1879  Monster Hunter Frontier Online      PS3     NaN  Role-Playing       NaN
# 7014  Monster Hunter Frontier Online     X360  2010.0  Role-Playing    Capcom
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 1879        0        0     0.05           0
# 7014        0        0     0.13           0

# %%
list = [1879, 7014]   # 수정
for idx in list:
  df.loc[idx,'Publisher'] = 'Capcom'   # 수정

df.loc[list]
# Out:
#                                 Name Platform    Year         Genre Publisher  \
# 1879  Monster Hunter Frontier Online      PS3     NaN  Role-Playing    Capcom
# 7014  Monster Hunter Frontier Online     X360  2010.0  Role-Playing    Capcom
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 1879        0        0     0.05           0
# 7014        0        0     0.13           0

# %%
df.loc[[27, 2070]] # 2
# Out:
#                 Name Platform    Year    Genre      Publisher NA_Sales  \
# 27    World of Tanks       PC  2011.0  Shooter  Wargaming.net        0
# 2070  World of Tanks     X360     NaN  Shooter            NaN        0
#
#      EU_Sales JP_Sales Other_Sales
# 27       0.23        0        0.06
# 2070     0.03        0           0

# %%
list = [27, 2070]   # 수정
for idx in list:
  df.loc[idx,'Publisher'] = 'Wargaming.net'   # 수정

df.loc[list]
# Out:
#                 Name Platform    Year    Genre      Publisher NA_Sales  \
# 27    World of Tanks       PC  2011.0  Shooter  Wargaming.net        0
# 2070  World of Tanks     X360     NaN  Shooter  Wargaming.net        0
#
#      EU_Sales JP_Sales Other_Sales
# 27       0.23        0        0.06
# 2070     0.03        0           0

# %%
df.loc[[6392, 15057]] # 3
# Out:
#                               Name Platform    Year    Genre Publisher  \
# 6392   Brothers in Arms: Furious 4     X360     NaN  Shooter       NaN
# 15057  Brothers in Arms: Furious 4      PS3  2012.0  Shooter   Ubisoft
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 6392      0.01        0        0           0
# 15057     0.01     0.05        0        0.02

# %%
list = [6392, 15057]   # 수정
for idx in list:
  df.loc[idx,'Publisher'] = 'Ubisoft'   # 수정

df.loc[list]
# Out:
#                               Name Platform    Year    Genre Publisher  \
# 6392   Brothers in Arms: Furious 4     X360     NaN  Shooter   Ubisoft
# 15057  Brothers in Arms: Furious 4      PS3  2012.0  Shooter   Ubisoft
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 6392      0.01        0        0           0
# 15057     0.01     0.05        0        0.02

# %%
df.loc[[8651, 10044, 14728, 15704]] # 4
# Out:
#                      Name Platform    Year     Genre Publisher NA_Sales  \
# 8651   Sonic the Hedgehog      PS3     NaN  Platform       NaN        0
# 10044  Sonic the Hedgehog     X360  2006.0  Platform      Sega     0.44
# 14728  Sonic the Hedgehog      GEN  1991.0  Platform      Sega     3.03
# 15704  Sonic the Hedgehog      PS3  2006.0  Platform      Sega     0.41
#
#       EU_Sales JP_Sales Other_Sales
# 8651      0.48        0           0
# 10044     0.49        0        0.11
# 14728     0.91     0.26        0.13
# 15704     0.07     0.04        0.66

# %%
list = [8651, 10044, 14728, 15704]   # 수정
for idx in list:
  df.loc[idx,'Publisher'] = 'Sega'   # 수정

df.loc[list]
# Out:
#                      Name Platform    Year     Genre Publisher NA_Sales  \
# 8651   Sonic the Hedgehog      PS3     NaN  Platform      Sega        0
# 10044  Sonic the Hedgehog     X360  2006.0  Platform      Sega     0.44
# 14728  Sonic the Hedgehog      GEN  1991.0  Platform      Sega     3.03
# 15704  Sonic the Hedgehog      PS3  2006.0  Platform      Sega     0.41
#
#       EU_Sales JP_Sales Other_Sales
# 8651      0.48        0           0
# 10044     0.49        0        0.11
# 14728     0.91     0.26        0.13
# 15704     0.07     0.04        0.66

# %% [markdown]
# ##### Publisher 결측치 data imputaion 후, 확인

# %%
df[df.Publisher.isnull()].shape
# Out:
# (54, 9)

# %%
df_publisher = df   
df_publisher.shape
# Out:
# (16597, 9)

# %% [markdown]
# #### Year

# %% [markdown]
# ##### Year 결측치 확인

# %%
# Year, Genre, Publisher 결측치 확인
# Year
year_null = df[df.Year.isnull()]
year_null
# Out:
#                                               Name Platform  Year       Genre  \
# 31                                       Rock Band     X360   NaN        Misc
# 109     Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN      Racing
# 273    Jewel Link Chronicles: Mountains of Madness       DS   NaN      Puzzle
# 358             Majesty 2: The Fantasy Kingdom Sim     X360   NaN  Simulation
# 430                                     Famista 64      N64   NaN      Sports
# ...                                            ...      ...   ...         ...
# 16239                                Freaky Flyers       GC   NaN      Racing
# 16274                               Space Invaders     2600   NaN     Shooter
# 16277                                Madden NFL 11      Wii   NaN      Sports
# 16424                               Yoostar on MTV     X360   NaN        Misc
# 16431                                  Bejeweled 3     X360   NaN      Puzzle
#
# ...

# %%
year_null_name = year_null.Name
year_null_name.head()
# Out:
# 31                                       Rock Band
# 109     Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)
# 273    Jewel Link Chronicles: Mountains of Madness
# 358             Majesty 2: The Fantasy Kingdom Sim
# 430                                     Famista 64
# Name: Name, dtype: object

# %%
year_null_name.duplicated().sum()
# Out:
# 37

# %%
year_name = year_null_name[year_null_name.duplicated()]
year_name.shape
# Out:
# (37,)

# %%
for name in year_name:
  tup = np.where(df['Name'] == name)  # tuple로 값 반환
  print(tup)          # tuple -> array로 변환
# Out:
# (array([ 2056,  2552,  5034,  5258, 10879, 16030]),)
# (array([ 3895,  4124,  7131, 12730]),)
# (array([   31,  4181, 10775, 12857]),)
# (array([ 2665,  4238,  6223, 12101]),)
# (array([ 3895,  4124,  7131, 12730]),)
# (array([ 6512,  8076, 11881, 12709, 15331]),)
# (array([6257, 8812]),)
# (array([ 5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]),)
# (array([ 675, 2457, 9297]),)
# (array([ 5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]),)
# (array([3347, 3775, 4815, 5592, 5849, 9640, 9957]),)
# (array([ 2710,  4608, 10268, 16431]),)
# (array([ 5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]),)
# (array([ 5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]),)
# (array([ 6375, 10533]),)
# (array([ 5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]),)
# (array([   31,  4181, 10775, 12857]),)
# (array([ 4488, 11664, 13292]),)
# (array([11507, 12087, 13577]),)
# (array([ 8638, 12306]),)
# (array([ 6512,  8076, 11881, 12709, 15331]),)
# ...

# %% [markdown]
# ##### Year 결측치 직접 확인 후, 대입

# %%
df.loc[[2056,  2552,  5034,  5258, 10879, 16030]] # 0
# Out:
#                      Name Platform    Year   Genre Publisher NA_Sales  \
# 2056   The Golden Compass      Wii     NaN  Action      Sega     0.26
# 2552   The Golden Compass      PSP     NaN  Action      Sega     0.11
# 5034   The Golden Compass      PS3  2007.0  Action      Sega     0.14
# 5258   The Golden Compass       DS  2007.0  Action      Sega     0.28
# 10879  The Golden Compass      PS2  2007.0  Action      Sega     0.13
# 16030  The Golden Compass     X360  2007.0  Action      Sega      0.3
#
#       EU_Sales JP_Sales Other_Sales
# 2056      0.28        0        0.07
# 2552      160K        0         0.1
# 5034       0.1        0        0.05
# 5258      0.25        0        0.06
# 10879        0        0        0.39
# 16030     0.12        0        0.04

# %%
list = [2056,  2552,  5034,  5258, 10879, 16030]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2007   # 수정

df.loc[list]
# Out:
#                      Name Platform    Year   Genre Publisher NA_Sales  \
# 2056   The Golden Compass      Wii  2007.0  Action      Sega     0.26
# 2552   The Golden Compass      PSP  2007.0  Action      Sega     0.11
# 5034   The Golden Compass      PS3  2007.0  Action      Sega     0.14
# 5258   The Golden Compass       DS  2007.0  Action      Sega     0.28
# 10879  The Golden Compass      PS2  2007.0  Action      Sega     0.13
# 16030  The Golden Compass     X360  2007.0  Action      Sega      0.3
#
#       EU_Sales JP_Sales Other_Sales
# 2056      0.28        0        0.07
# 2552      160K        0         0.1
# 5034       0.1        0        0.05
# 5258      0.25        0        0.06
# 10879        0        0        0.39
# 16030     0.12        0        0.04

# %%
df.loc[[ 3895,  4124,  7131, 12730]] # 1
# Out:
#                                     Name Platform    Year   Genre  \
# 3895   WRC: FIA World Rally Championship      PS3     NaN  Racing
# 4124   WRC: FIA World Rally Championship     X360     NaN  Racing
# 7131   WRC: FIA World Rally Championship       PC     NaN  Racing
# 12730  WRC: FIA World Rally Championship      PSP  2005.0  Racing
#
#                          Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 3895              Black Bean Games        0     0.15     0.01        0.05
# 4124              Black Bean Games        0      0.1        0        0.02
# 7131              Black Bean Games        0     0.01        0           0
# 12730  Sony Computer Entertainment     0.02     0.01        0        0.01

# %%
list = [ 3895,  4124,  7131, 12730]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2005   # 수정

df.loc[list]
# Out:
#                                     Name Platform    Year   Genre  \
# 3895   WRC: FIA World Rally Championship      PS3  2005.0  Racing
# 4124   WRC: FIA World Rally Championship     X360  2005.0  Racing
# 7131   WRC: FIA World Rally Championship       PC  2005.0  Racing
# 12730  WRC: FIA World Rally Championship      PSP  2005.0  Racing
#
#                          Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 3895              Black Bean Games        0     0.15     0.01        0.05
# 4124              Black Bean Games        0      0.1        0        0.02
# 7131              Black Bean Games        0     0.01        0           0
# 12730  Sony Computer Entertainment     0.02     0.01        0        0.01

# %%
df.loc[[31,  4181, 10775, 12857]] # 2
# Out:
#             Name Platform  Year Genre        Publisher NA_Sales EU_Sales  \
# 31     Rock Band     X360   NaN  Misc  Electronic Arts     1.93     0.34
# 4181   Rock Band      Wii   NaN  Misc        MTV Games     1.35     0.56
# 10775  Rock Band      PS3   NaN  Misc  Electronic Arts     0.99     0.41
# 12857  Rock Band      PS2   NaN  Misc  Electronic Arts     0.71     0.06
#
#       JP_Sales Other_Sales
# 31           0        0.21
# 4181         0         0.2
# 10775        0        0.22
# 12857        0        0.35

# %%
df.loc[[2665,  4238,  6223, 12101]] # 3
# Out:
#                   Name Platform    Year Genre                     Publisher  \
# 2665   Rock Revolution       DS  2008.0  Misc  Konami Digital Entertainment
# 4238   Rock Revolution      Wii     NaN  Misc                       Unknown
# 6223   Rock Revolution      PS3     NaN  Misc                       Unknown
# 12101  Rock Revolution     X360  2008.0  Misc  Konami Digital Entertainment
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 2665       0.1        0        0        0.01
# 4238      0.07        0        0        0.01
# 6223      0.25        0        0        0.02
# 12101     0.25        0        0        0.02

# %%
list = [2665,  4238,  6223, 12101]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2008   # 수정

df.loc[list]
# Out:
#                   Name Platform    Year Genre                     Publisher  \
# 2665   Rock Revolution       DS  2008.0  Misc  Konami Digital Entertainment
# 4238   Rock Revolution      Wii  2008.0  Misc                       Unknown
# 6223   Rock Revolution      PS3  2008.0  Misc                       Unknown
# 12101  Rock Revolution     X360  2008.0  Misc  Konami Digital Entertainment
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 2665       0.1        0        0        0.01
# 4238      0.07        0        0        0.01
# 6223      0.25        0        0        0.02
# 12101     0.25        0        0        0.02

# %%
df.loc[[3895,  4124,  7131, 12730]] # 4 - #1번이랑 똑같음
# Out:
#                                     Name Platform    Year   Genre  \
# 3895   WRC: FIA World Rally Championship      PS3  2005.0  Racing
# 4124   WRC: FIA World Rally Championship     X360  2005.0  Racing
# 7131   WRC: FIA World Rally Championship       PC  2005.0  Racing
# 12730  WRC: FIA World Rally Championship      PSP  2005.0  Racing
#
#                          Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 3895              Black Bean Games        0     0.15     0.01        0.05
# 4124              Black Bean Games        0      0.1        0        0.02
# 7131              Black Bean Games        0     0.01        0           0
# 12730  Sony Computer Entertainment     0.02     0.01        0        0.01

# %%
df.loc[[6512,  8076, 11881, 12709, 15331]] # 5
# Out:
#                  Name Platform    Year   Genre  \
# 6512   Happy Feet Two      Wii     NaN  Action
# 8076   Happy Feet Two      PS3     NaN  Action
# 11881  Happy Feet Two      3DS  2011.0  Action
# 12709  Happy Feet Two     X360     NaN  Action
# 15331  Happy Feet Two       DS     NaN  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 6512   Warner Bros. Interactive Entertainment     0.07     0.01        0
# 8076   Warner Bros. Interactive Entertainment     0.09     0.01        0
# 11881  Warner Bros. Interactive Entertainment     0.08     0.02        0
# 12709  Warner Bros. Interactive Entertainment     0.08     0.01        0
# 15331  Warner Bros. Interactive Entertainment     0.09     0.02        0
#
#       Other_Sales
# 6512         0.01
# 8076         0.01
# 11881        0.01
# 12709        0.01
# 15331        0.01

# %%
list = [6512,  8076, 11881, 12709, 15331]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2011   # 수정

df.loc[list]
# Out:
#                  Name Platform    Year   Genre  \
# 6512   Happy Feet Two      Wii  2011.0  Action
# 8076   Happy Feet Two      PS3  2011.0  Action
# 11881  Happy Feet Two      3DS  2011.0  Action
# 12709  Happy Feet Two     X360  2011.0  Action
# 15331  Happy Feet Two       DS  2011.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 6512   Warner Bros. Interactive Entertainment     0.07     0.01        0
# 8076   Warner Bros. Interactive Entertainment     0.09     0.01        0
# 11881  Warner Bros. Interactive Entertainment     0.08     0.02        0
# 12709  Warner Bros. Interactive Entertainment     0.08     0.01        0
# 15331  Warner Bros. Interactive Entertainment     0.09     0.02        0
#
#       Other_Sales
# 6512         0.01
# 8076         0.01
# 11881        0.01
# 12709        0.01
# 15331        0.01

# %%
df.loc[[6257, 8812]] # 6 -nan값
# Out:
#                                  Name Platform  Year    Genre Publisher  \
# 6257  Combat Elite: WWII Paratroopers      PS2   NaN  Shooter   Unknown
# 8812  Combat Elite: WWII Paratroopers       XB   NaN  Shooter   Unknown
#
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 6257     0.03     0.02        0        0.01
# 8812     0.02     0.01        0           0

# %%
df.loc[[5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]] # 7
# Out:
#                                Name Platform    Year   Genre  \
# 5309   LEGO Harry Potter: Years 5-7      PS3     NaN  Action
# 9239   LEGO Harry Potter: Years 5-7      Wii     NaN  Action
# 9761   LEGO Harry Potter: Years 5-7      3DS     NaN  Action
# 10320  LEGO Harry Potter: Years 5-7       PC     NaN  Action
# 10345  LEGO Harry Potter: Years 5-7      PSP     NaN  Action
# 10562  LEGO Harry Potter: Years 5-7       DS     NaN  Action
# 11934  LEGO Harry Potter: Years 5-7      PSV  2012.0  Action
# 15316  LEGO Harry Potter: Years 5-7     X360     NaN  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 5309   Warner Bros. Interactive Entertainment     0.36     0.45        0
# 9239   Warner Bros. Interactive Entertainment     0.76     0.47        0
# 9761   Warner Bros. Interactive Entertainment     0.18     0.19        0
# 10320  Warner Bros. Interactive Entertainment     0.05     0.14        0
# ...

# %%
list = [5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2012   # 수정

df.loc[list]
# Out:
#                                Name Platform    Year   Genre  \
# 5309   LEGO Harry Potter: Years 5-7      PS3  2012.0  Action
# 9239   LEGO Harry Potter: Years 5-7      Wii  2012.0  Action
# 9761   LEGO Harry Potter: Years 5-7      3DS  2012.0  Action
# 10320  LEGO Harry Potter: Years 5-7       PC  2012.0  Action
# 10345  LEGO Harry Potter: Years 5-7      PSP  2012.0  Action
# 10562  LEGO Harry Potter: Years 5-7       DS  2012.0  Action
# 11934  LEGO Harry Potter: Years 5-7      PSV  2012.0  Action
# 15316  LEGO Harry Potter: Years 5-7     X360  2012.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 5309   Warner Bros. Interactive Entertainment     0.36     0.45        0
# 9239   Warner Bros. Interactive Entertainment     0.76     0.47        0
# 9761   Warner Bros. Interactive Entertainment     0.18     0.19        0
# 10320  Warner Bros. Interactive Entertainment     0.05     0.14        0
# ...

# %%
df.loc[[675, 2457, 9297]] # 8
# Out:
#                   Name Platform    Year Genre            Publisher NA_Sales  \
# 675   Battle vs. Chess      PS3     NaN  Misc  TopWare Interactive        0
# 2457  Battle vs. Chess     X360  2011.0  Misc  TopWare Interactive        0
# 9297  Battle vs. Chess       PC     NaN  Misc  TopWare Interactive        0
#
#      EU_Sales JP_Sales Other_Sales
# 675      0.04        0        0.01
# 2457     0.03        0           0
# 9297     0.02        0        0.01

# %%
list = [675, 2457, 9297]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2011   # 수정

df.loc[list]
# Out:
#                   Name Platform    Year Genre            Publisher NA_Sales  \
# 675   Battle vs. Chess      PS3  2011.0  Misc  TopWare Interactive        0
# 2457  Battle vs. Chess     X360  2011.0  Misc  TopWare Interactive        0
# 9297  Battle vs. Chess       PC  2011.0  Misc  TopWare Interactive        0
#
#      EU_Sales JP_Sales Other_Sales
# 675      0.04        0        0.01
# 2457     0.03        0           0
# 9297     0.02        0        0.01

# %%
df.loc[[5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]] # 9 -7과 중복
# Out:
#                                Name Platform    Year   Genre  \
# 5309   LEGO Harry Potter: Years 5-7      PS3  2012.0  Action
# 9239   LEGO Harry Potter: Years 5-7      Wii  2012.0  Action
# 9761   LEGO Harry Potter: Years 5-7      3DS  2012.0  Action
# 10320  LEGO Harry Potter: Years 5-7       PC  2012.0  Action
# 10345  LEGO Harry Potter: Years 5-7      PSP  2012.0  Action
# 10562  LEGO Harry Potter: Years 5-7       DS  2012.0  Action
# 11934  LEGO Harry Potter: Years 5-7      PSV  2012.0  Action
# 15316  LEGO Harry Potter: Years 5-7     X360  2012.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 5309   Warner Bros. Interactive Entertainment     0.36     0.45        0
# 9239   Warner Bros. Interactive Entertainment     0.76     0.47        0
# 9761   Warner Bros. Interactive Entertainment     0.18     0.19        0
# 10320  Warner Bros. Interactive Entertainment     0.05     0.14        0
# ...

# %%
df.loc[[3347, 3775, 4815, 5592, 5849, 9640, 9957]] # 10
# Out:
#                             Name Platform    Year   Genre  \
# 3347  LEGO Batman: The Videogame      Wii     NaN  Action
# 3775  LEGO Batman: The Videogame       DS  2008.0  Action
# 4815  LEGO Batman: The Videogame       PC  2008.0  Action
# 5592  LEGO Batman: The Videogame     X360  2008.0  Action
# 5849  LEGO Batman: The Videogame      PS3  2008.0  Action
# 9640  LEGO Batman: The Videogame      PS2  2008.0  Action
# 9957  LEGO Batman: The Videogame      PSP     NaN  Action
#
#                                    Publisher NA_Sales EU_Sales JP_Sales  \
# 3347  Warner Bros. Interactive Entertainment     1.86     1.02        0
# 3775  Warner Bros. Interactive Entertainment     1.79     1.06        0
# 4815  Warner Bros. Interactive Entertainment     0.02     0.03        0
# 5592  Warner Bros. Interactive Entertainment     2.03     1.03        0
# 5849  Warner Bros. Interactive Entertainment     0.72     0.42        0
# ...

# %%
list = [3347, 3775, 4815, 5592, 5849, 9640, 9957]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2008   # 수정

df.loc[list]
# Out:
#                             Name Platform    Year   Genre  \
# 3347  LEGO Batman: The Videogame      Wii  2008.0  Action
# 3775  LEGO Batman: The Videogame       DS  2008.0  Action
# 4815  LEGO Batman: The Videogame       PC  2008.0  Action
# 5592  LEGO Batman: The Videogame     X360  2008.0  Action
# 5849  LEGO Batman: The Videogame      PS3  2008.0  Action
# 9640  LEGO Batman: The Videogame      PS2  2008.0  Action
# 9957  LEGO Batman: The Videogame      PSP  2008.0  Action
#
#                                    Publisher NA_Sales EU_Sales JP_Sales  \
# 3347  Warner Bros. Interactive Entertainment     1.86     1.02        0
# 3775  Warner Bros. Interactive Entertainment     1.79     1.06        0
# 4815  Warner Bros. Interactive Entertainment     0.02     0.03        0
# 5592  Warner Bros. Interactive Entertainment     2.03     1.03        0
# 5849  Warner Bros. Interactive Entertainment     0.72     0.42        0
# ...

# %%
df.loc[[2710,  4608, 10268, 16431]] # 11
# Out:
#               Name Platform    Year   Genre     Publisher NA_Sales EU_Sales  \
# 2710   Bejeweled 3       PC  2010.0  Puzzle  PopCap Games     0.02     0.05
# 4608   Bejeweled 3      PS3     NaN  Puzzle       Unknown     0.13        0
# 10268  Bejeweled 3       DS     NaN  Puzzle       Unknown     0.32     0.02
# 16431  Bejeweled 3     X360     NaN  Puzzle       Unknown     0.13        0
#
#       JP_Sales Other_Sales
# 2710         0        0.01
# 4608         0        0.01
# 10268        0        0.03
# 16431        0        0.01

# %%
list = [2710,  4608, 10268, 16431]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2010   # 수정

df.loc[list]
# Out:
#               Name Platform    Year   Genre     Publisher NA_Sales EU_Sales  \
# 2710   Bejeweled 3       PC  2010.0  Puzzle  PopCap Games     0.02     0.05
# 4608   Bejeweled 3      PS3  2010.0  Puzzle       Unknown     0.13        0
# 10268  Bejeweled 3       DS  2010.0  Puzzle       Unknown     0.32     0.02
# 16431  Bejeweled 3     X360  2010.0  Puzzle       Unknown     0.13        0
#
#       JP_Sales Other_Sales
# 2710         0        0.01
# 4608         0        0.01
# 10268        0        0.03
# 16431        0        0.01

# %%
df.loc[[5309,  9239,  9761, 10320, 10345, 10562, 11934, 15316]] # 12,13,14,16 - 7,9와 중복
# Out:
#                                Name Platform    Year   Genre  \
# 5309   LEGO Harry Potter: Years 5-7      PS3  2012.0  Action
# 9239   LEGO Harry Potter: Years 5-7      Wii  2012.0  Action
# 9761   LEGO Harry Potter: Years 5-7      3DS  2012.0  Action
# 10320  LEGO Harry Potter: Years 5-7       PC  2012.0  Action
# 10345  LEGO Harry Potter: Years 5-7      PSP  2012.0  Action
# 10562  LEGO Harry Potter: Years 5-7       DS  2012.0  Action
# 11934  LEGO Harry Potter: Years 5-7      PSV  2012.0  Action
# 15316  LEGO Harry Potter: Years 5-7     X360  2012.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 5309   Warner Bros. Interactive Entertainment     0.36     0.45        0
# 9239   Warner Bros. Interactive Entertainment     0.76     0.47        0
# 9761   Warner Bros. Interactive Entertainment     0.18     0.19        0
# 10320  Warner Bros. Interactive Entertainment     0.05     0.14        0
# ...

# %%
df.loc[[6375, 10533]] # 15 - nan
# Out:
#               Name Platform  Year   Genre Publisher NA_Sales EU_Sales  \
# 6375   Backbreaker      PS3   NaN  Sports   Unknown     0.16        0
# 10533  Backbreaker     X360   NaN  Sports   Unknown     0.17        0
#
#       JP_Sales Other_Sales
# 6375         0        0.01
# 10533        0        0.01

# %%
df.loc[[4488, 11664, 13292]] # 18
# Out:
#                                           Name Platform    Year   Genre  \
# 4488   The Lord of the Rings: War in the North      PS3     NaN  Action
# 11664  The Lord of the Rings: War in the North     X360     NaN  Action
# 13292  The Lord of the Rings: War in the North       PC  2011.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 4488   Warner Bros. Interactive Entertainment     0.25     0.45     0.01
# 11664  Warner Bros. Interactive Entertainment     0.52     0.26        0
# 13292  Warner Bros. Interactive Entertainment     0.04     0.11        0
#
#       Other_Sales
# 4488         0.15
# 11664        0.08
# 13292        0.03

# %%
list = [4488, 11664, 13292]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2011   # 수정

df.loc[list]
# Out:
#                                           Name Platform    Year   Genre  \
# 4488   The Lord of the Rings: War in the North      PS3  2011.0  Action
# 11664  The Lord of the Rings: War in the North     X360  2011.0  Action
# 13292  The Lord of the Rings: War in the North       PC  2011.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 4488   Warner Bros. Interactive Entertainment     0.25     0.45     0.01
# 11664  Warner Bros. Interactive Entertainment     0.52     0.26        0
# 13292  Warner Bros. Interactive Entertainment     0.04     0.11        0
#
#       Other_Sales
# 4488         0.15
# 11664        0.08
# 13292        0.03

# %%
df.loc[[11507, 12087, 13577]] # 19
# Out:
#                 Name Platform    Year   Genre        Publisher NA_Sales  \
# 11507  NBA Live 2003       XB     NaN  Sports  Electronic Arts     0.31
# 12087  NBA Live 2003       GC     NaN  Sports  Electronic Arts     0.23
# 13577  NBA Live 2003      PS2  2002.0  Sports  Electronic Arts     1.25
#
#       EU_Sales JP_Sales Other_Sales
# 11507     0.04        0        0.01
# 12087     0.06        0        0.01
# 13577     0.15     0.03        0.22

# %%
list = [11507, 12087, 13577]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2002   # 수정

df.loc[list]
# Out:
#                 Name Platform    Year   Genre        Publisher NA_Sales  \
# 11507  NBA Live 2003       XB  2002.0  Sports  Electronic Arts     0.31
# 12087  NBA Live 2003       GC  2002.0  Sports  Electronic Arts     0.23
# 13577  NBA Live 2003      PS2  2002.0  Sports  Electronic Arts     1.25
#
#       EU_Sales JP_Sales Other_Sales
# 11507     0.04        0        0.01
# 12087     0.06        0        0.01
# 13577     0.15     0.03        0.22

# %%
df.loc[[8638, 12306]] # 20 -nan
# Out:
#                 Name Platform  Year       Genre      Publisher NA_Sales  \
# 8638   Port Royale 3     X360   NaN  Simulation  Kalypso Media     0.06
# 12306  Port Royale 3      PS3   NaN  Simulation  Kalypso Media     0.06
#
#       EU_Sales JP_Sales Other_Sales
# 8638         0        0           0
# 12306        0        0        0.01

# %%
df.loc[[6512,  8076, 11881, 12709, 15331]] # 21
# Out:
#                  Name Platform    Year   Genre  \
# 6512   Happy Feet Two      Wii  2011.0  Action
# 8076   Happy Feet Two      PS3  2011.0  Action
# 11881  Happy Feet Two      3DS  2011.0  Action
# 12709  Happy Feet Two     X360  2011.0  Action
# 15331  Happy Feet Two       DS  2011.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 6512   Warner Bros. Interactive Entertainment     0.07     0.01        0
# 8076   Warner Bros. Interactive Entertainment     0.09     0.01        0
# 11881  Warner Bros. Interactive Entertainment     0.08     0.02        0
# 12709  Warner Bros. Interactive Entertainment     0.08     0.01        0
# 15331  Warner Bros. Interactive Entertainment     0.09     0.02        0
#
#       Other_Sales
# 6512         0.01
# 8076         0.01
# 11881        0.01
# 12709        0.01
# 15331        0.01

# %%
df.loc[[ 4196, 13255, 13356]] # 23
# Out:
#                          Name Platform  Year   Genre Publisher NA_Sales  \
# 4196   Test Drive Unlimited 2     X360   NaN  Racing     Atari      0.3
# 13255  Test Drive Unlimited 2       PC   NaN  Racing     Atari     0.05
# 13356  Test Drive Unlimited 2      PS3   NaN  Racing     Atari     0.16
#
#       EU_Sales JP_Sales Other_Sales
# 4196      0.32        0        0.07
# 13255     0.11        0        0.03
# 13356     0.35     0.01        0.12

# %%
df.loc[[1251,  4657,  6354, 13487]] # 25
# Out:
#        Name Platform    Year   Genre    Publisher NA_Sales EU_Sales JP_Sales  \
# 1251   GRID      PS3  2008.0  Racing  Codemasters     0.31     0.57     0.03
# 4657   GRID     X360  2008.0  Racing  Codemasters     0.33     0.44     0.01
# 6354   GRID       DS     NaN  Racing  Codemasters     0.04     0.01        0
# 13487  GRID       PC     NaN  Racing  Codemasters        0     0.03        0
#
#       Other_Sales
# 1251          0.2
# 4657         0.09
# 6354            0
# 13487        0.01

# %%
list = [1251,  4657,  6354, 13487]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2008   # 수정

df.loc[list]
# Out:
#        Name Platform    Year   Genre    Publisher NA_Sales EU_Sales JP_Sales  \
# 1251   GRID      PS3  2008.0  Racing  Codemasters     0.31     0.57     0.03
# 4657   GRID     X360  2008.0  Racing  Codemasters     0.33     0.44     0.01
# 6354   GRID       DS  2008.0  Racing  Codemasters     0.04     0.01        0
# 13487  GRID       PC  2008.0  Racing  Codemasters        0     0.03        0
#
#       Other_Sales
# 1251          0.2
# 4657         0.09
# 6354            0
# 13487        0.01

# %%
df.loc[[729,  1396,  2444,  3291, 13582]] # 26
# Out:
#                                                     Name Platform    Year  \
# 729    The Chronicles of Narnia: The Lion, The Witch ...       DS  2005.0
# 1396   The Chronicles of Narnia: The Lion, The Witch ...      PS2  2005.0
# 2444   The Chronicles of Narnia: The Lion, The Witch ...       XB  2005.0
# 3291   The Chronicles of Narnia: The Lion, The Witch ...      GBA     NaN
# 13582  The Chronicles of Narnia: The Lion, The Witch ...       GC     NaN
#
#         Genre                   Publisher NA_Sales EU_Sales JP_Sales  \
# 729    Action  Disney Interactive Studios     0.15     0.02        0
# 1396   Action  Disney Interactive Studios     0.36     0.01        0
# 2444   Action  Disney Interactive Studios     0.15     0.04        0
# 3291   Action  Disney Interactive Studios     0.48     0.18        0
# 13582  Action  Disney Interactive Studios     0.22     0.06        0
#
#       Other_Sales
# 729          0.01
# 1396         0.06
# 2444         0.01
# 3291         0.01
# ...

# %%
list = [729,  1396,  2444,  3291, 13582]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2005   # 수정

df.loc[list]
# Out:
#                                                     Name Platform    Year  \
# 729    The Chronicles of Narnia: The Lion, The Witch ...       DS  2005.0
# 1396   The Chronicles of Narnia: The Lion, The Witch ...      PS2  2005.0
# 2444   The Chronicles of Narnia: The Lion, The Witch ...       XB  2005.0
# 3291   The Chronicles of Narnia: The Lion, The Witch ...      GBA  2005.0
# 13582  The Chronicles of Narnia: The Lion, The Witch ...       GC  2005.0
#
#         Genre                   Publisher NA_Sales EU_Sales JP_Sales  \
# 729    Action  Disney Interactive Studios     0.15     0.02        0
# 1396   Action  Disney Interactive Studios     0.36     0.01        0
# 2444   Action  Disney Interactive Studios     0.15     0.04        0
# 3291   Action  Disney Interactive Studios     0.48     0.18        0
# 13582  Action  Disney Interactive Studios     0.22     0.06        0
#
#       Other_Sales
# 729          0.01
# 1396         0.06
# 2444         0.01
# 3291         0.01
# ...

# %%
df.loc[[10895, 14118]] # 27
# Out:
#                          Name Platform  Year   Genre Publisher NA_Sales  \
# 10895  All-Star Baseball 2005      PS2   NaN  Sports   Unknown     0.16
# 14118  All-Star Baseball 2005       XB   NaN  Sports   Unknown     0.11
#
#       EU_Sales JP_Sales Other_Sales
# 10895     0.12        0        0.04
# 14118     0.03        0        0.01

# %%
df.loc[[2337,  5503, 11730, 13945, 14302]] # 28
# Out:
#                                  Name Platform    Year   Genre Publisher  \
# 2337   Captain America: Super Soldier       DS     NaN  Action      Sega
# 5503   Captain America: Super Soldier      PS3  2011.0  Action      Sega
# 11730  Captain America: Super Soldier      3DS  2011.0  Action      Sega
# 13945  Captain America: Super Soldier     X360  2011.0  Action      Sega
# 14302  Captain America: Super Soldier      Wii     NaN  Action      Sega
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 2337      0.05        0        0           0
# 5503       0.1     0.07        0        0.03
# 11730     0.05     0.02        0        0.01
# 13945     0.11     0.05        0        0.01
# 14302     0.05        0        0           0

# %%
list = [2337,  5503, 11730, 13945, 14302]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2011   # 수정

df.loc[list]
# Out:
#                                  Name Platform    Year   Genre Publisher  \
# 2337   Captain America: Super Soldier       DS  2011.0  Action      Sega
# 5503   Captain America: Super Soldier      PS3  2011.0  Action      Sega
# 11730  Captain America: Super Soldier      3DS  2011.0  Action      Sega
# 13945  Captain America: Super Soldier     X360  2011.0  Action      Sega
# 14302  Captain America: Super Soldier      Wii  2011.0  Action      Sega
#
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 2337      0.05        0        0           0
# 5503       0.1     0.07        0        0.03
# 11730     0.05     0.02        0        0.01
# 13945     0.11     0.05        0        0.01
# 14302     0.05        0        0           0

# %%
df.loc[[10636, 12260, 14435]] # 29
# Out:
#                                     Name Platform    Year   Genre  \
# 10636  PDC World Championship Darts 2008      PSP     NaN  Sports
# 12260  PDC World Championship Darts 2008      Wii  2008.0  Sports
# 14435  PDC World Championship Darts 2008       DS     NaN  Sports
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 10636  Oxygen Interactive     0.01        0        0           0
# 12260  Oxygen Interactive     0.02     0.21        0        0.01
# 14435             Unknown     0.01        0        0           0

# %%
list = [10636, 12260, 14435]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2008   # 수정

df.loc[list]
# Out:
#                                     Name Platform    Year   Genre  \
# 10636  PDC World Championship Darts 2008      PSP  2008.0  Sports
# 12260  PDC World Championship Darts 2008      Wii  2008.0  Sports
# 14435  PDC World Championship Darts 2008       DS  2008.0  Sports
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 10636  Oxygen Interactive     0.01        0        0           0
# 12260  Oxygen Interactive     0.02     0.21        0        0.01
# 14435             Unknown     0.01        0        0           0

# %%
df.loc[[12702, 14621]] # 30
# Out:
#                                         Name Platform  Year   Genre  \
# 12702  Robert Ludlum's The Bourne Conspiracy      PS3   NaN  Action
# 14621  Robert Ludlum's The Bourne Conspiracy     X360   NaN  Action
#
#            Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 12702  Vivendi Games     0.18     0.14        0        0.06
# 14621  Vivendi Games     0.26     0.14        0        0.04

# %%
df.loc[[13186, 14940]] # 31
# Out:
#                             Name Platform  Year      Genre Publisher NA_Sales  \
# 13186  The Daring Game for Girls       DS   NaN  Adventure   Unknown     0.11
# 14940  The Daring Game for Girls      Wii   NaN  Adventure   Unknown     0.09
#
#       EU_Sales JP_Sales Other_Sales
# 13186        0        0        0.01
# 14940        0        0        0.01

# %%
df.loc[[12416, 15012]] # 32
# Out:
#                           Name Platform  Year   Genre  \
# 12416  Silent Hill: Homecoming      PS3   NaN  Action
# 15012  Silent Hill: Homecoming     X360   NaN  Action
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 12416  Konami Digital Entertainment    0.18M     0.15        0        0.06
# 15012  Konami Digital Entertainment     0.25     0.16        0        0.04

# %%
df.loc[[6512,  8076, 11881, 12709, 15331]] # 34
# Out:
#                  Name Platform    Year   Genre  \
# 6512   Happy Feet Two      Wii  2011.0  Action
# 8076   Happy Feet Two      PS3  2011.0  Action
# 11881  Happy Feet Two      3DS  2011.0  Action
# 12709  Happy Feet Two     X360  2011.0  Action
# 15331  Happy Feet Two       DS  2011.0  Action
#
#                                     Publisher NA_Sales EU_Sales JP_Sales  \
# 6512   Warner Bros. Interactive Entertainment     0.07     0.01        0
# 8076   Warner Bros. Interactive Entertainment     0.09     0.01        0
# 11881  Warner Bros. Interactive Entertainment     0.08     0.02        0
# 12709  Warner Bros. Interactive Entertainment     0.08     0.01        0
# 15331  Warner Bros. Interactive Entertainment     0.09     0.02        0
#
#       Other_Sales
# 6512         0.01
# 8076         0.01
# 11881        0.01
# 12709        0.01
# 15331        0.01

# %%
df.loc[[ 2270, 15896]] # 35
# Out:
#                Name Platform  Year         Genre Publisher NA_Sales EU_Sales  \
# 2270   Virtua Quest      PS2   NaN  Role-Playing   Unknown     0.01     0.01
# 15896  Virtua Quest       GC   NaN  Role-Playing   Unknown     0.01        0
#
#       JP_Sales Other_Sales
# 2270         0           0
# 15896        0           0

# %%
df.loc[[9820, 13733, 16194]] # 36
# Out:
#               Name Platform    Year    Genre     Publisher NA_Sales EU_Sales  \
# 9820   Singularity       PC  2010.0  Shooter  Mastertronic       0M     0.04
# 13733  Singularity      PS3     NaN  Shooter       Unknown     0.17     0.04
# 16194  Singularity     X360     NaN  Shooter       Unknown     0.24     0.05
#
#       JP_Sales Other_Sales
# 9820         0        0.01
# 13733     0.01        0.03
# 16194        0        0.02

# %%
list = [9820, 13733, 16194]   # 수정
for idx in list:
  df.loc[idx,'Year'] = 2010   # 수정

df.loc[list]
# Out:
#               Name Platform    Year    Genre     Publisher NA_Sales EU_Sales  \
# 9820   Singularity       PC  2010.0  Shooter  Mastertronic       0M     0.04
# 13733  Singularity      PS3  2010.0  Shooter       Unknown     0.17     0.04
# 16194  Singularity     X360  2010.0  Shooter       Unknown     0.24     0.05
#
#       JP_Sales Other_Sales
# 9820         0        0.01
# 13733     0.01        0.03
# 16194        0        0.02

# %% [markdown]
# ##### Year 결측치 data imputaion 후, 확인

# %%
df[df.Year.isnull()]
# Out:
#                                                     Name Platform  Year  \
# 31                                             Rock Band     X360   NaN
# 109           Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN
# 273          Jewel Link Chronicles: Mountains of Madness       DS   NaN
# 358                   Majesty 2: The Fantasy Kingdom Sim     X360   NaN
# 430                                           Famista 64      N64   NaN
# ...                                                  ...      ...   ...
# 16129  Super Robot Wars OG Saga: Masou Kishin II - Re...      PSP   NaN
# 16239                                      Freaky Flyers       GC   NaN
# 16274                                     Space Invaders     2600   NaN
# 16277                                      Madden NFL 11      Wii   NaN
# 16424                                     Yoostar on MTV     X360   NaN
#
#             Genre           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# ...

# %%
df_year_null = df   # df - year 결측치 포함 살려둠
df_year_null.shape
# Out:
# (16597, 9)

# %% [markdown]
# #### 결측치 제거 - 다른 데이터를 채우기 위해 결측치 imputation 후, 마지막에 한 번에 제거

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16597 entries, 0 to 16596
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16597 non-null  object
#  1   Platform     16597 non-null  object
#  2   Year         16366 non-null  float64
#  3   Genre        16567 non-null  object
#  4   Publisher    16543 non-null  object
#  5   NA_Sales     16597 non-null  object
#  6   EU_Sales     16597 non-null  object
#  7   JP_Sales     16597 non-null  object
#  8   Other_Sales  16597 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 1.1+ MB

# %%
df.dropna(axis=0, inplace=True)

# %%
# 결측치 제거 후, Year type int로 변경
df = df.astype({'Year':'int'})   # 특정 열 type 변경
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16300 entries, 0 to 16596
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16300 non-null  object
#  1   Platform     16300 non-null  object
#  2   Year         16300 non-null  int64
#  3   Genre        16300 non-null  object
#  4   Publisher    16300 non-null  object
#  5   NA_Sales     16300 non-null  object
#  6   EU_Sales     16300 non-null  object
#  7   JP_Sales     16300 non-null  object
#  8   Other_Sales  16300 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.2+ MB

# %%
df = df.reset_index(drop=True)  # 인덱스 재정렬
df
# Out:
#                                                  Name Platform  Year  \
# 0                        Candace Kane's Candy Factory       DS  2008
# 1                                      The Munchables      Wii  2009
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010
# 3                    Deal or No Deal: Special Edition       DS  2010
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010
# ...                                               ...      ...   ...
# 16295                         Ice Age 2: The Meltdown       GC  2006
# 16296                     Rainbow Islands: Revolution      PSP  2005
# 16297                                        NBA 2K16      PS3  2015
# 16298                     Toukiden: The Age of Demons      PSV  2013
# 16299                        The King of Fighters '95       PS  1996
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %% [markdown]
# ### 1-3) 단위 변경

# %% [markdown]
# ##### sales 단위 오류 변경 - M,K 문자열 삭제

# %%
df1 = df

# %%
# sales인 애들만 추출
df_sales = df1.loc[:,'NA_Sales':'Other_Sales']
df_sales
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 0         0.04        0        0           0
# 1         0.17        0        0        0.01
# 2            0        0     0.02           0
# 3         0.04        0        0           0
# 4         0.12     0.09        0        0.04
# ...        ...      ...      ...         ...
# 16295     0.15     0.04        0        0.01
# 16296     0.01        0        0           0
# 16297     0.44     0.19     0.03        0.13
# 16298     0.05     0.05     0.25        0.03
# 16299        0        0     0.16        0.01
#
# [16300 rows x 4 columns]

# %%
# sales 인 애들 중에 숫자외의 문자 존재 행 출력
import re   # 정규표현식

df_sales_str = df_sales[df_sales['NA_Sales'].str.contains(r'([A-Z]+)', na = False) | df_sales['EU_Sales'].str.contains(r'([A-Z]+)', na = False) | df_sales['JP_Sales'].str.contains(r'([A-Z]+)', na = False) | df_sales['Other_Sales'].str.contains(r'([A-Z]+)', na = False)]
df_sales_str
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 10        480K    0.33M       0K        0.06
# 35         0.3    0.03M     0.04        0.03
# 44         60K     0.08     0.16        0.03
# 62        0.01        0        0          0M
# 71        0.22     0.06        0       0.01M
# ...        ...      ...      ...         ...
# 16227     0.01       0K        0           0
# 16273        0       0M     0.02           0
# 16280     320K     0.22        0        0.04
# 16282        0     0.03       0M           0
# 16293     4.18     0.26     0.01         80K
#
# [767 rows x 4 columns]

# %%
# M,K 문자만 지워주기

df_sales['NA_Sales'] = df_sales['NA_Sales'].str.replace('K|M','')
df_sales['EU_Sales'] = df_sales['EU_Sales'].str.replace('K|M','')
df_sales['JP_Sales'] = df_sales['JP_Sales'].str.replace('K|M','')
df_sales['Other_Sales'] = df_sales['Other_Sales'].str.replace('K|M','')

df_sales_str = df_sales[df_sales['NA_Sales'].str.contains(r'([A-Z]+)', na = False) | df_sales['EU_Sales'].str.contains(r'([A-Z]+)', na = False) | df_sales['JP_Sales'].str.contains(r'([A-Z]+)', na = False) | df_sales['Other_Sales'].str.contains(r'([A-Z]+)', na = False)]
df_sales_str
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# Empty DataFrame
# ...

# %% [markdown]
# ##### 소수점 자리 맞춰주기

# %% [markdown]
# ###### NA_Sales

# %%
# 문자를 지우고, 0이랑 소수점 2자리가 아닌애들 소수점 2자리수로 맞춰주기 

df_sales = df_sales.astype('str')
df_sales.loc[10]
# Out:
# NA_Sales        480
# EU_Sales       0.33
# JP_Sales          0
# Other_Sales    0.06
# Name: 10, dtype: object

# %%
# 소수점 기준으로 분리
df_sales_split = df_sales
split = df_sales_split['NA_Sales'].str.split('.', expand=True)

split
# Out:
#        0     1
# 0      0    04
# 1      0    17
# 2      0  None
# 3      0    04
# 4      0    12
# ...   ..   ...
# 16295  0    15
# 16296  0    01
# 16297  0    44
# 16298  0    05
# 16299  0  None
#
# [16300 rows x 2 columns]

# %%
split_copy = split

# %%
# 정수로 표현된 데이터 -> 소수점 추가
split_4 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 4 :
    split_4 = split_4.append(split.loc[[n]])

split_4 = split_4.loc[:,0].str[:1] + '.' + split_4.loc[:,0].str[1:4]
pd.DataFrame(split_4)
# Out:
#            0
# 1933   4.100
# 4394   1.210
# 4891   1.610
# 5201   1.210
# 6811   1.610
# 9631   1.780
# 9669   2.930
# 11790  2.010
# 13683  2.570

# %%
split_3 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 3 and len(split.loc[n,0]) < 4:
    split_3 = split_3.append(split.loc[[n]])

split_3 = split_3.loc[:,0].str[:1] + '.' + split_3.loc[:,0].str[1:3]
pd.DataFrame(split_3)
# Out:
#           0
# 10     4.80
# 1341   4.90
# 1438   2.40
# 1811   1.50
# 3439   1.90
# 4945   1.00
# 5189   1.70
# 6045   1.50
# 6096   4.50
# 6480   2.20
# 6578   3.10
# 6903   8.20
# 7070   2.90
# 7312   1.30
# 7749   1.50
# 7999   1.00
# 8541   1.30
# 8693   1.20
# 8868   2.90
# 10185  2.80
# 10644  5.40
# 11786  5.50
# 11950  1.00
# 12300  7.70
# 12650  3.40
# 13105  2.20
# 13317  6.00
# 13638  1.30
# 14814  2.70
# 14832  4.20
# 15147  2.80
# 15900  1.20
# 16033  7.20
# 16194  4.70
# 16280  3.20

# %%
split_2 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 2 and len(split.loc[n,0]) < 3 :
     split_2 = split_2.append(split.loc[[n]])

split_2 = split_2.loc[:,0].str[:1] + '.' + split_2.loc[:,0].str[1:2]
pd.DataFrame(split_2)
# Out:
#          0
# 44     6.0
# 1189   2.3
# 2627   2.0
# 2861   4.1
# 2877   3.0
# 2965   1.4
# 3206   5.0
# 3272   7.0
# 3296   1.5
# 4127   2.9
# 4268   1.4
# 5667   4.0
# 5951   2.0
# 5982   6.0
# 6819   1.1
# 6929   2.0
# 6989   8.0
# 7698   1.1
# 8100   6.0
# 8103   5.0
# 8722   5.0
# 9102   2.0
# 9301   6.0
# 9335   1.0
# 10184  1.0
# 10314  2.6
# 10368  5.0
# 12120  1.0
# 12360  1.5
# 12524  2.0
# 12828  9.0
# 12882  1.2
# 13552  9.0
# 13922  3.0
# 14088  9.0
# 14150  4.0
# 15337  3.0
# 16233  1.4

# %%
split_copy
# Out:
#        0     1
# 0      0    04
# 1      0    17
# 2      0  None
# 3      0    04
# 4      0    12
# ...   ..   ...
# 16295  0    15
# 16296  0    01
# 16297  0    44
# 16298  0    05
# 16299  0  None
#
# [16300 rows x 2 columns]

# %%
# 인덱스에 맞춰 데이터를 대체하기 위해 인덱스 열 추가
split_copy['index'] = split_copy.index
split_copy
# Out:
#        0     1  index
# 0      0    04      0
# 1      0    17      1
# 2      0  None      2
# 3      0    04      3
# 4      0    12      4
# ...   ..   ...    ...
# 16295  0    15  16295
# 16296  0    01  16296
# 16297  0    44  16297
# 16298  0    05  16298
# 16299  0  None  16299
#
# [16300 rows x 3 columns]

# %%
split_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16300 entries, 0 to 16299
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       16300 non-null  object
#  1   1       11782 non-null  object
#  2   index   16300 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 382.2+ KB

# %%
# 정수->소수로 변환한 데이터 원본 데이터에 합쳐주기
for idx in split_4.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_4[idx]

for idx in split_3.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_3[idx]

for idx in split_2.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_2[idx]

# %%
split_copy.loc[1933]
# Out:
# 0        4.100
# 1         None
# index     1933
# Name: 1933, dtype: object

# %%
split_co = split_copy

# %%
split_co.isnull().sum()
# Out:
# 0           0
# 1        4518
# index       0
# dtype: int64

# %%
split_co = split_co.fillna(0)
split_co.isnull().sum()
# Out:
# 0        0
# 1        0
# index    0
# dtype: int64

# %%
split_co
# Out:
#        0   1  index
# 0      0  04      0
# 1      0  17      1
# 2      0   0      2
# 3      0  04      3
# 4      0  12      4
# ...   ..  ..    ...
# 16295  0  15  16295
# 16296  0  01  16296
# 16297  0  44  16297
# 16298  0  05  16298
# 16299  0   0  16299
#
# [16300 rows x 3 columns]

# %%
split_co.loc[0,1] != 0
# Out:
# True

# %%
split_co.loc[1933,1] != 0
# Out:
# False

# %%
# 두번째 칼럼이 0이 아니면 첫번째 칼럼에 값을 넣어줌

for idx in split_co.index:
  if split_co.loc[idx,1] != 0 :
      split_co.loc[idx,0] = split_co.loc[idx,0] + '.'
      split_co.loc[idx,0] = split_co.loc[idx,0] + str(split_co.loc[idx,1])

# %%
split_co.loc[1933]
# Out:
# 0        4.100
# 1            0
# index     1933
# Name: 1933, dtype: object

# %%
split_co[0]
# Out:
# 0        0.04
# 1        0.17
# 2           0
# 3        0.04
# 4        0.12
#          ...
# 16295    0.15
# 16296    0.01
# 16297    0.44
# 16298    0.05
# 16299       0
# Name: 0, Length: 16300, dtype: object

# %%
df_sales['NA_Sales'] = split_co[0]
df_sales.loc[1933]
# Out:
# NA_Sales       4.100
# EU_Sales        1.89
# JP_Sales        1.45
# Other_Sales     0.16
# Name: 1933, dtype: object

# %% [markdown]
# ###### EU_Sales

# %%
df_sales_split = df_sales.astype('str')
split = df_sales_split['EU_Sales'].str.split('.', expand=True)

split
# Out:
#        0     1
# 0      0  None
# 1      0  None
# 2      0  None
# 3      0  None
# 4      0    09
# ...   ..   ...
# 16295  0    04
# 16296  0  None
# 16297  0    19
# 16298  0    05
# 16299  0  None
#
# [16300 rows x 2 columns]

# %%
split_copy = split

# 정수로 표현된 데이터 -> 소수점 추가
split_4 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 4 :
    split_4 = split_4.append(split.loc[[n]])

split_4 = split_4.loc[:,0].str[:1] + '.' + split_4.loc[:,0].str[1:4]
pd.DataFrame(split_4)


split_3 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 3 and len(split.loc[n,0]) < 4:
    split_3 = split_3.append(split.loc[[n]])

split_3 = split_3.loc[:,0].str[:1] + '.' + split_3.loc[:,0].str[1:3]
pd.DataFrame(split_3)


split_2 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 2 and len(split.loc[n,0]) < 3 :
     split_2 = split_2.append(split.loc[[n]])

split_2 = split_2.loc[:,0].str[:1] + '.' + split_2.loc[:,0].str[1:2]
pd.DataFrame(split_2)
# Out:
#          0
# 135    5.0
# 985    8.0
# 1080   8.0
# 1248   5.0
# 1357   2.0
# 1455   5.0
# 1534   4.0
# 2162   1.0
# 2684   1.0
# 2859   4.0
# 2861   2.9
# 3296   1.1
# 3484   3.0
# 4012   4.0
# 4517   7.0
# 4626   7.0
# 4740   3.0
# 5403   1.0
# 5612   4.0
# 6008   3.0
# 6314   2.0
# 7197   7.0
# 7382   4.0
# 7821   5.0
# 7860   4.0
# 7933   2.0
# 8281   2.0
# 9054   5.0
# 9244   3.0
# 9502   4.0
# 10286  1.0
# 10491  5.0
# 10951  1.1
# 12301  5.0
# 12360  1.2
# 12821  4.0
# 12837  5.0
# 13501  5.0
# 13583  9.0
# 15093  2.0
# 15246  1.0
# 15470  2.0
# 15825  6.0
# 15835  7.0
# 16077  5.0

# %%
# 인덱스에 맞춰 데이터를 대체하기 위해 인덱스 열 추가
split_copy['index'] = split_copy.index
split_copy
# Out:
#        0     1  index
# 0      0  None      0
# 1      0  None      1
# 2      0  None      2
# 3      0  None      3
# 4      0    09      4
# ...   ..   ...    ...
# 16295  0    04  16295
# 16296  0  None  16296
# 16297  0    19  16297
# 16298  0    05  16298
# 16299  0  None  16299
#
# [16300 rows x 3 columns]

# %%
# 정수->소수로 변환한 데이터 원본 데이터에 합쳐주기
for idx in split_4.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_4[idx]

for idx in split_3.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_3[idx]

for idx in split_2.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_2[idx]

# %%
split_copy.loc[1604]
# Out:
# 0        2.560
# 1         None
# index     1604
# Name: 1604, dtype: object

# %%
split_co = split_copy
split_co = split_co.fillna(0)
split_co.isnull().sum()
# Out:
# 0        0
# 1        0
# index    0
# dtype: int64

# %%
# 두번째 칼럼이 0이 아니면 첫번째 칼럼에 값을 넣어줌

for idx in split_co.index:
  if split_co.loc[idx,1] != 0 :
      split_co.loc[idx,0] = split_co.loc[idx,0] + '.'
      split_co.loc[idx,0] = split_co.loc[idx,0] + str(split_co.loc[idx,1])

# %%
split_co.loc[4]
# Out:
# 0        0.09
# 1          09
# index       4
# Name: 4, dtype: object

# %%
df_sales['EU_Sales'] = split_co[0]
df_sales.loc[1604]
# Out:
# NA_Sales        2.64
# EU_Sales       2.560
# JP_Sales        0.16
# Other_Sales     1.14
# Name: 1604, dtype: object

# %% [markdown]
# ###### JP_Sales

# %%
df_sales_split = df_sales.astype('str')
split = df_sales_split['JP_Sales'].str.split('.', expand=True)

split
# Out:
#        0     1
# 0      0  None
# 1      0  None
# 2      0    02
# 3      0  None
# 4      0  None
# ...   ..   ...
# 16295  0  None
# 16296  0  None
# 16297  0    03
# 16298  0    25
# 16299  0    16
#
# [16300 rows x 2 columns]

# %%
split_copy = split

# 정수로 표현된 데이터 -> 소수점 추가
split_4 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 4 :
    split_4 = split_4.append(split.loc[[n]])

split_4 = split_4.loc[:,0].str[:1] + '.' + split_4.loc[:,0].str[1:4]
pd.DataFrame(split_4)


split_3 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 3 and len(split.loc[n,0]) < 4:
    split_3 = split_3.append(split.loc[[n]])

split_3 = split_3.loc[:,0].str[:1] + '.' + split_3.loc[:,0].str[1:3]
pd.DataFrame(split_3)


split_2 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 2 and len(split.loc[n,0]) < 3 :
     split_2 = split_2.append(split.loc[[n]])

split_2 = split_2.loc[:,0].str[:1] + '.' + split_2.loc[:,0].str[1:2]
pd.DataFrame(split_2)
# Out:
#          0
# 817    3.0
# 1465   4.0
# 1576   5.0
# 2808   3.0
# 3157   8.0
# 3179   2.0
# 3386   3.0
# 4196   8.0
# 6199   4.0
# 7514   1.0
# 7698   1.0
# 7800   7.0
# 8030   1.0
# 8678   2.0
# 8962   9.0
# 9038   1.0
# 9106   4.0
# 10064  7.0
# 10470  2.0
# 12284  9.0
# 12317  5.0
# 13216  8.0
# 13819  2.0
# 14146  8.0

# %%
# 인덱스에 맞춰 데이터를 대체하기 위해 인덱스 열 추가
split_copy['index'] = split_copy.index
split_copy
# Out:
#        0     1  index
# 0      0  None      0
# 1      0  None      1
# 2      0    02      2
# 3      0  None      3
# 4      0  None      4
# ...   ..   ...    ...
# 16295  0  None  16295
# 16296  0  None  16296
# 16297  0    03  16297
# 16298  0    25  16298
# 16299  0    16  16299
#
# [16300 rows x 3 columns]

# %%
# 정수->소수로 변환한 데이터 원본 데이터에 합쳐주기
for idx in split_4.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_4[idx]

for idx in split_3.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_3[idx]

for idx in split_2.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_2[idx]

# %%
split_copy.loc[3527]
# Out:
# 0        2.780
# 1         None
# index     3527
# Name: 3527, dtype: object

# %%
split_co = split_copy
split_co = split_co.fillna(0)
split_co.isnull().sum()
# Out:
# 0        0
# 1        0
# index    0
# dtype: int64

# %%
# 두번째 칼럼이 0이 아니면 첫번째 칼럼에 값을 넣어줌

for idx in split_co.index:
  if split_co.loc[idx,1] != 0 :
      split_co.loc[idx,0] = split_co.loc[idx,0] + '.'
      split_co.loc[idx,0] = split_co.loc[idx,0] + str(split_co.loc[idx,1])

# %%
split_co.loc[2]
# Out:
# 0        0.02
# 1          02
# index       2
# Name: 2, dtype: object

# %%
df_sales['JP_Sales'] = split_co[0]
df_sales.loc[3527]
# Out:
# NA_Sales        1.62
# EU_Sales        0.77
# JP_Sales       2.780
# Other_Sales     0.14
# Name: 3527, dtype: object

# %% [markdown]
# ###### Other_Sales

# %%
df_sales_split = df_sales.astype('str')
split = df_sales_split['Other_Sales'].str.split('.', expand=True)

split
# Out:
#        0     1
# 0      0  None
# 1      0    01
# 2      0  None
# 3      0  None
# 4      0    04
# ...   ..   ...
# 16295  0    01
# 16296  0  None
# 16297  0    13
# 16298  0    03
# 16299  0    01
#
# [16300 rows x 2 columns]

# %%
split_copy = split

# 정수로 표현된 데이터 -> 소수점 추가

split_3 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 3 and len(split.loc[n,0]) < 4:
    split_3 = split_3.append(split.loc[[n]])

split_3 = split_3.loc[:,0].str[:1] + '.' + split_3.loc[:,0].str[1:3]
pd.DataFrame(split_3)


split_2 = pd.DataFrame()
for n in range(16300):  
  if len(split.loc[n,0]) >= 2 and len(split.loc[n,0]) < 3 :
     split_2 = split_2.append(split.loc[[n]])

split_2 = split_2.loc[:,0].str[:1] + '.' + split_2.loc[:,0].str[1:2]
pd.DataFrame(split_2)
# Out:
#          0
# 242    1.0
# 393    3.0
# 634    3.0
# 864    1.0
# 1199   5.0
# 2424   4.0
# 2429   8.0
# 3423   1.0
# 4826   3.0
# 4930   1.0
# 4963   2.0
# 5102   1.0
# 5404   6.0
# 5487   4.0
# 5939   5.0
# 6333   2.0
# 6418   5.0
# 6634   5.0
# 7041   8.0
# 7351   2.0
# 7925   2.0
# 8016   3.0
# 8553   1.0
# 9003   3.0
# 9089   3.0
# 9416   6.0
# 9744   1.0
# 10024  3.0
# 10405  1.0
# 11760  2.0
# 11774  1.0
# 12125  2.0
# 12199  5.0
# 13396  1.0
# 14360  3.0
# 14405  1.0
# 14529  5.0
# 14770  2.0
# 15849  7.0
# 16293  8.0

# %%
# 인덱스에 맞춰 데이터를 대체하기 위해 인덱스 열 추가
split_copy['index'] = split_copy.index
split_copy
# Out:
#        0     1  index
# 0      0  None      0
# 1      0    01      1
# 2      0  None      2
# 3      0  None      3
# 4      0    04      4
# ...   ..   ...    ...
# 16295  0    01  16295
# 16296  0  None  16296
# 16297  0    13  16297
# 16298  0    03  16298
# 16299  0    01  16299
#
# [16300 rows x 3 columns]

# %%
# 정수->소수로 변환한 데이터 원본 데이터에 합쳐주기

for idx in split_3.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_3[idx]

for idx in split_2.index:
  if split_copy['index'].equals(idx) :
    print('x')
  else:  
    split_copy.loc[idx,0] = split_2[idx]

# %%
split_copy.loc[5279]
# Out:
# 0        3.40
# 1        None
# index    5279
# Name: 5279, dtype: object

# %%
split_co = split_copy
split_co = split_co.fillna(0)
split_co.isnull().sum()
# Out:
# 0        0
# 1        0
# index    0
# dtype: int64

# %%
# 두번째 칼럼이 0이 아니면 첫번째 칼럼에 값을 넣어줌

for idx in split_co.index:
  if split_co.loc[idx,1] != 0 :
      split_co.loc[idx,0] = split_co.loc[idx,0] + '.'
      split_co.loc[idx,0] = split_co.loc[idx,0] + str(split_co.loc[idx,1])

# %%
split_co.loc[1]
# Out:
# 0        0.01
# 1          01
# index       1
# Name: 1, dtype: object

# %%
df_sales['Other_Sales'] = split_co[0]
df_sales.loc[5279]
# Out:
# NA_Sales       2.11
# EU_Sales       0.94
# JP_Sales       0.12
# Other_Sales    3.40
# Name: 5279, dtype: object

# %% [markdown]
# ##### type 변환 - float

# %%
df_sales
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 0         0.04        0        0           0
# 1         0.17        0        0        0.01
# 2            0        0     0.02           0
# 3         0.04        0        0           0
# 4         0.12     0.09        0        0.04
# ...        ...      ...      ...         ...
# 16295     0.15     0.04        0        0.01
# 16296     0.01        0        0           0
# 16297     0.44     0.19     0.03        0.13
# 16298     0.05     0.05     0.25        0.03
# 16299        0        0     0.16        0.01
#
# [16300 rows x 4 columns]

# %%
df_sales[df_sales['NA_Sales'].str.contains('2.3.2')]
# Out:
#      NA_Sales EU_Sales JP_Sales Other_Sales
# 1189    2.3.2     2.26     4.22        0.58

# %%
df_sales[df_sales['NA_Sales'].str.contains('4.1')]
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 1933     4.100     1.89     1.45        0.16
# 2861    4.1.49   2.9.02     3.77        8.46
# 6438      4.14     2.21        0        0.56
# 7460      4.15     1.92     0.06        0.64
# 7869      4.12     1.77     0.87        0.19
# 16293     4.18     0.26     0.01         8.0

# %%
# float으로 type 변환, 마지막에 소수점 2자리수로 다 맞춰주기
df_sales = df_sales.astype('float')
df_sales = round(df_sales, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-181-b0e97a4381a3> in <module>
#       1 # float으로 type 변환, 마지막에 소수점 2자리수로 다 맞춰주기
# ----> 2 df_sales = df_sales.astype('float')
#       3 df_sales = round(df_sales, 2)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
str = df_sales.isin(['2.3.2'])
df_sa = df_sales[~str]
df_sa
# Out:
#       NA_Sales EU_Sales JP_Sales Other_Sales
# 0         0.04        0        0           0
# 1         0.17        0        0        0.01
# 2            0        0     0.02           0
# 3         0.04        0        0           0
# 4         0.12     0.09        0        0.04
# ...        ...      ...      ...         ...
# 16295     0.15     0.04        0        0.01
# 16296     0.01        0        0           0
# 16297     0.44     0.19     0.03        0.13
# 16298     0.05     0.05     0.25        0.03
# 16299        0        0     0.16        0.01
#
# [16300 rows x 4 columns]

# %%
df_sales.loc[3527]
# Out:
# NA_Sales           1.62
# EU_Sales           0.77
# JP_Sales          2.780
# Other_Sales    2.780.14
# Name: 3527, dtype: object

# %%
df_sales.loc[890]
# Out:
# NA_Sales       0.47
# EU_Sales          0
# JP_Sales          0
# Other_Sales    0.04
# Name: 890, dtype: object

# %% [markdown]
# ## 2. Data Visualization

# %%
df1 = df  # df 중간저장
df1
# Out:
#                                                  Name Platform  Year  \
# 0                        Candace Kane's Candy Factory       DS  2008
# 1                                      The Munchables      Wii  2009
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010
# 3                    Deal or No Deal: Special Edition       DS  2010
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010
# ...                                               ...      ...   ...
# 16295                         Ice Age 2: The Meltdown       GC  2006
# 16296                     Rainbow Islands: Revolution      PSP  2005
# 16297                                        NBA 2K16      PS3  2015
# 16298                     Toukiden: The Age of Demons      PSV  2013
# 16299                        The King of Fighters '95       PS  1996
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16300 entries, 0 to 16299
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         16300 non-null  object
#  1   Platform     16300 non-null  object
#  2   Year         16300 non-null  int64
#  3   Genre        16300 non-null  object
#  4   Publisher    16300 non-null  object
#  5   NA_Sales     16300 non-null  object
#  6   EU_Sales     16300 non-null  object
#  7   JP_Sales     16300 non-null  object
#  8   Other_Sales  16300 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.1+ MB

# %%
# sales 인 애들 중에 숫자외의 문자 존재 행 출력 - 581개
df2 = df1[df1['NA_Sales'].str.contains(r'([A-Z]+)', na = False) | df1['EU_Sales'].str.contains(r'([A-Z]+)', na = False) | df1['JP_Sales'].str.contains(r'([A-Z]+)', na = False) | df1['Other_Sales'].str.contains(r'([A-Z]+)', na = False)]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#                                         Name Platform  Year      Genre  \
# 10                               Ford Racing       PS  2001     Racing
# 35                 Advance Wars: Dual Strike       DS  2005   Strategy
# 44              Resident Evil: Revelations 2      PS3  2015     Action
# 62                           SD Gundam Force      GBA  2004    Shooter
# 71              Teenage Mutant Ninja Turtles       XB  2003     Action
# ...                                      ...      ...   ...        ...
# 16227                        Planet Monsters      GBA  2001     Action
# 16273                           Koihime Enbu      PS4  2016   Fighting
# 16280                   Gex: Enter the Gecko       PS  1998   Platform
# 16282  Captain Morgane and the Golden Turtle       DS  2012  Adventure
# ...

# %%
# 문자를 포함하는 581개 행 삭제
df1 = df1[~df1['NA_Sales'].str.contains('K|M')]
df1 = df1[~df1['EU_Sales'].str.contains('K|M')]
df1 = df1[~df1['JP_Sales'].str.contains('K|M')]
df1 = df1[~df1['Other_Sales'].str.contains('K|M')]

df2 = df1[df1['NA_Sales'].str.contains(r'([A-Z]+)', na = False) | df1['EU_Sales'].str.contains(r'([A-Z]+)', na = False) | df1['JP_Sales'].str.contains(r'([A-Z]+)', na = False) | df1['Other_Sales'].str.contains(r'([A-Z]+)', na = False)]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   import sys
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales]
# Index: []

# %%
df1
# Out:
#                                                  Name Platform  Year  \
# 0                        Candace Kane's Candy Factory       DS  2008
# 1                                      The Munchables      Wii  2009
# 2      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010
# 3                    Deal or No Deal: Special Edition       DS  2010
# 4           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010
# ...                                               ...      ...   ...
# 16295                         Ice Age 2: The Meltdown       GC  2006
# 16296                     Rainbow Islands: Revolution      PSP  2005
# 16297                                        NBA 2K16      PS3  2015
# 16298                     Toukiden: The Age of Demons      PSV  2013
# 16299                        The King of Fighters '95       PS  1996
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15533 entries, 0 to 16299
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         15533 non-null  object
#  1   Platform     15533 non-null  object
#  2   Year         15533 non-null  int64
#  3   Genre        15533 non-null  object
#  4   Publisher    15533 non-null  object
#  5   NA_Sales     15533 non-null  object
#  6   EU_Sales     15533 non-null  object
#  7   JP_Sales     15533 non-null  object
#  8   Other_Sales  15533 non-null  object
#  9   Total_Sales  15533 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.3+ MB

# %%
# float type으로 변환
df1['NA_Sales'] = df1['NA_Sales'].astype('float')
df1['NA_Sales'] = round(df1['NA_Sales'], 2)

df1['EU_Sales'] = df1['EU_Sales'].astype('float')
df1['EU_Sales'] = round(df1['EU_Sales'], 2)

df1['JP_Sales'] = df1['JP_Sales'].astype('float')
df1['JP_Sales'] =round(df1['JP_Sales'], 2)

df1['Other_Sales'] = df1['Other_Sales'].astype('float')
df1['Other_Sales'] = round(df1['Other_Sales'], 2)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15533 entries, 0 to 16299
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         15533 non-null  object
#  1   Platform     15533 non-null  object
#  2   Year         15533 non-null  int64
#  3   Genre        15533 non-null  object
#  4   Publisher    15533 non-null  object
#  5   NA_Sales     15533 non-null  float64
#  6   EU_Sales     15533 non-null  float64
#  7   JP_Sales     15533 non-null  float64
#  8   Other_Sales  15533 non-null  float64
#  9   Total_Sales  15533 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
# 질문 1 : 지역에 따라서 선호하는 게임 장르가 다를까 라는 질문에 대답을 하셔야합니다.
# 지역에 따른 게임 장르 그래프 
# Total sales 생성
df1['Total_Sales'] = df1['NA_Sales'] + df1['EU_Sales'] + df1['JP_Sales'] + df1['Other_Sales']

df_genre = df1.groupby(by=['Genre'])['Total_Sales'].sum() # 전 대륙 선호하는 게임 장르
df_genre = df_genre.reset_index()

df_genre_na = df1.groupby(by=['Genre'])['NA_Sales'].sum() # 북미 선호하는 게임 장르
df_genre_na = df_genre_na.reset_index()

df_genre_eu = df1.groupby(by=['Genre'])['EU_Sales'].sum() # 유럽 선호하는 게임 장르
df_genre_eu = df_genre_eu.reset_index()

df_genre_jp = df1.groupby(by=['Genre'])['JP_Sales'].sum() # 일본 선호하는 게임 장르
df_genre_jp = df_genre_jp.reset_index()

df_genre_ot = df1.groupby(by=['Genre'])['Other_Sales'].sum() # 일본 선호하는 게임 장르
df_genre_ot = df_genre_ot.reset_index()

df_genre = df_genre.combine_first(df_genre_na).combine_first(df_genre_eu).combine_first(df_genre_jp).combine_first(df_genre_ot)
df_genre = df_genre.set_index("Genre")

sns.set(style='darkgrid')
plt.figure(figsize=(15, 10))
plt.title("Preferred Game Genre by Continent", fontsize=30)
plt.xlabel("Genre of game", fontsize=20)
plt.ylabel("Total sales volume", fontsize=20)

sns.lineplot(data=df_genre, markers=True)

# %% [markdown]
# NA(북미)에서는 Action 게임 장르가 제일 인기가 많고, 그 다음으로는 Sports 게임이 인기가 많다.
#
# EU(유럽) 또한 Action 다음 Sports 순으로 같다.
#
# JP(일본)에서는 Role-playing 게임이 압도적으로 인기가 많고, 그 다음으로는 action 장르가 인기가 많은 것을 확인 할 수 있다.

# %%
# 질문2 : 연도별 게임의 트렌드가 있을까 라는 질문에 대답을 하셔야합니다.
# 연도별 게임 장르 그래프
year_sale_dx = df1.groupby(by=['Year', 'Genre'])['Total_Sales'].sum().reset_index()
year_sale = year_sale_dx.groupby(by=['Year'])['Total_Sales'].transform(max) == year_sale_dx['Total_Sales']
year_sale_max = year_sale_dx[year_sale].reset_index(drop=True)

genre = year_sale_max['Genre']

plt.figure(figsize=(30, 18))
g = sns.barplot(x='Year', y='Total_Sales', data=year_sale_max)
index = 0
for value in year_sale_max['Total_Sales']:
    g.text(index, value + 1, str(genre[index] + '-' +str(round(value, 2))), color='#000', size=20, rotation= 90, ha="center")
    index += 1

plt.title("Yearly game trends", fontsize=30)
plt.xlabel("Year", fontsize=20)
plt.ylabel("Total sales volume", fontsize=20)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 2000년대 이전에는 단순한 shooting, puzzle, platform 게임을 주로 이용하였으며,
#
# 2000년대 이후, 컴퓨터가 많이 발전하면서 다양한 action 게임이 트렌드로 자리 잡았다.
#
# 2006년부터는 sport 게임을 압도적으로 많이 이용하며 sports와 action이 트렌드로 자리 잡았다.
